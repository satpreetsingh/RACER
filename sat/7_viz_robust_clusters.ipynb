# %%
# visualize_clusters.ipynb
import pandas as pd
import sys
import pandas as pd
import matplotlib.pyplot as plt
import textwrap
import glob
import seaborn as sns
import numpy as np
from collections import defaultdict
import matplotlib.backends.backend_pdf
import os
import glob
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
import utils

matplotlib.rcParams["font.family"] = "Arial"  # or 'Helvetica' if available


# YYYYMMDD = "20231209"
YYYYMMDD = "20231227"
CLUSTER_DIR = f"./outputs/{YYYYMMDD}/clusters/"  # Input
RECLUSTER_DIR = f"./outputs/{YYYYMMDD}/recluster/"  # Input
OUTPUT_DIR = f"./outputs/{YYYYMMDD}/"  # TODO: change var name to Base-dir
OUTPUT_REPORT_FILE = f"{OUTPUT_DIR}/cluster_report_robust.txt"
OUTPUT_CLUSTER_DEFS_FILE = f"{OUTPUT_DIR}/cluster_def_all.csv"
OUTPUT_ROBUST_CLUSTERS_PRIMARY_FILE = f"{OUTPUT_DIR}/robust_primary_cluster_all.csv"
OUTPUT_ROBUST_CLUSTERS_SECONDARY_FILE = f"{OUTPUT_DIR}/robust_secondary_cluster_all.csv"
# if not os.path.exists(OUTPUT_DIR):
#     os.mkdir(OUTPUT_DIR)


questions_file = "prompts/questions_8.txt"
questions_df = pd.read_csv(questions_file, sep="\t")
questions_dict = {
    f"Q{(row.question_number-1):02d}": row.question
    for index, row in questions_df.iterrows()
}

cluster_defs = glob.glob(CLUSTER_DIR + "/Q*metadata*.csv")
cluster_defs.sort()
print(cluster_defs[:5])
print(pd.read_csv(cluster_defs[0]).head())
print()

cluster_files = glob.glob(CLUSTER_DIR + "/Q*cluster*.csv")
cluster_files.sort()
print(cluster_files[:5])
print(
    pd.read_csv(cluster_files[0]).head()
)  # Has secondary clusters. Note columns: subject_id top_level_cluster_id  secondary_cluster_ids
print(
    pd.read_csv(cluster_files[3]).head()
)  # No secondary clusters. Note columns: subject_id cluster_ids
print()

recluster_files = glob.glob(RECLUSTER_DIR + "/Q*recluster*.tsv")
recluster_files.sort()
print(recluster_files[:5])
print(
    pd.read_csv(recluster_files[0], sep="\t").head()
)  # Has secondary clusters. Note columns: subject_id top_level_cluster_id  secondary_cluster_ids
print(
    pd.read_csv(recluster_files[3], sep="\t").head()
)  # Has secondary clusters with dummy assignments. Use the respective cluster_file to figure out if one-level or two-level clustering has been done
print()
# Out:
# ['./outputs/20231227/clusters/Q00_metadata.csv', './outputs/20231227/clusters/Q01_metadata.csv', './outputs/20231227/clusters/Q02_metadata.csv', './outputs/20231227/clusters/Q03_metadata.csv', './outputs/20231227/clusters/Q04_metadata.csv']
#   cluster_id                    cluster_name
# 0         C1            Young Adults (22-33)  \
# 1         C2      Middle-aged Adults (34-45)
# 2         C3            Older Adults (46-60)
# 3         C4          Seniors (61 and above)
# 4         C5  Unclear/irrelevant/no response
#
#                                  cluster_description
# 0       Subjects who are between 22 and 33 years old
# 1       Subjects who are between 34 and 45 years old
# 2       Subjects who are between 46 and 60 years old
# 3             Subjects who are 61 years old or above
# 4  Subjects who have not provided their age or th...
#
# ['./outputs/20231227/clusters/Q00_clusters.csv', './outputs/20231227/clusters/Q01_clusters.csv', './outputs/20231227/clusters/Q02_clusters.csv', './outputs/20231227/clusters/Q03_clusters.csv', './outputs/20231227/clusters/Q04_clusters.csv']
#   subject_id top_level_cluster_id  secondary_cluster_ids
# 0       C001                   C1                    NaN
# 1       C002                   C3                    NaN
# 2       C003                   C4                    NaN
# 3       C004                   C1                    NaN
# 4       C005                   C1                    NaN
#   subject_id cluster_ids
# 0       C001          C2
# 1       C002          C1
# 2       C003          C1
# 3       C004          C2
# 4       C005          C2
#
# ['./outputs/20231227/recluster/Q00_recluster.01.tsv', './outputs/20231227/recluster/Q00_recluster.02.tsv', './outputs/20231227/recluster/Q00_recluster.03.tsv', './outputs/20231227/recluster/Q00_recluster.04.tsv', './outputs/20231227/recluster/Q01_recluster.01.tsv']
#   subject_id top_level_cluster_id secondary_cluster_ids
# 0       C001                   C1                  C1.1
# 1       C002                   C3                  C3.1
# 2       C003                   C4                  C4.1
# 3       C004                   C1                  C1.1
# 4       C005                   C1                  C1.1
#   subject_id top_level_cluster_id secondary_cluster_ids
# 0       C001                   C1                  C1.1
# 1       C002                   C3                  C3.1
# 2       C003                   C4                  C4.1
# 3       C004                   C1                  C1.1
# 4       C005                   C1                  C1.1

# %%
def explode_cluster_ids(df, column="cluster_ids"):
    assert column in df.columns, df.columns
    df[column] = df[column].str.split(",")
    df = df.explode(column)
    df[column] = df[column].str.strip()
    df = df.reset_index(drop=True)
    return df


def get_cluster_count_mean_stds(exploded_df, column="cluster_ids"):
    # Get per-cluster mean and std (over iterations) of number of subjects assigned to each cluster (in exploded df format)
    assert "iteration" in exploded_df.columns
    assert "subject_id" in exploded_df.columns
    assert column in exploded_df.columns
    per_iteration_counts = (
        exploded_df.groupby([column, "iteration"])
        .agg(subject_id_count=("subject_id", "count"))
        .reset_index()
    )
    per_cluster_mean_stds = (
        per_iteration_counts.groupby([column])
        .agg(
            count_mean=("subject_id_count", "mean"),
            count_std=("subject_id_count", "std"),
        )
        .reset_index()
    )
    return per_cluster_mean_stds


# Utils
def get_robust_clusters(exploded_df, column="cluster_ids"):
    """Get robust cluster assignments (non-exclusive) are those that have a frequency >= 0.5 (frequency over iterations)"""
    assert [
        col in exploded_df.columns.tolist()
        for col in ["subject_id", "iteration", column]
    ]
    num_total_iterations = exploded_df["iteration"].unique().shape[0]
    threshold = np.ceil(num_total_iterations / 2)

    # calculate how many times each cluster is assigned to each subject across iterations
    repeats_per_cluster_subject = exploded_df.groupby(["subject_id", column]).agg(
        num_iterations=(column, "count")
    )
    # get robust clusters
    robust_cluster_subject = repeats_per_cluster_subject[
        repeats_per_cluster_subject["num_iterations"] >= threshold
    ].reset_index()
    # aggregate to one line per subject
    robust_cluster_subject = robust_cluster_subject.groupby("subject_id").agg(
        robust_cluster_ids=(column, lambda x: ",".join(x))
    )
    return robust_cluster_subject


def get_robust_clusters(exploded_df, column="cluster_ids"):
    """Get robust cluster assignments (non-exclusive) are those that have a frequency >= 0.5 (frequency over iterations)"""
    assert all(
        [
            col in exploded_df.columns.tolist()
            for col in ["subject_id", "iteration", column]
        ]
    )
    num_total_iterations = exploded_df["iteration"].nunique()
    threshold = np.ceil(num_total_iterations / 2)

    # Calculate how many times each cluster is assigned to each subject across iterations
    repeats_per_cluster_subject = exploded_df.groupby(["subject_id", column]).agg(
        num_iterations=(column, "count")
    )

    # Calculate the fraction of times each cluster is assigned
    repeats_per_cluster_subject["fraction"] = (
        repeats_per_cluster_subject["num_iterations"] / num_total_iterations
    )

    # Get robust clusters
    robust_cluster_subject = repeats_per_cluster_subject[
        repeats_per_cluster_subject["num_iterations"] >= threshold
    ].reset_index()

    # Aggregate to one line per subject and include fractions
    robust_cluster_subject = robust_cluster_subject.groupby("subject_id").agg(
        robust_cluster_ids=(column, lambda x: ",".join(x.astype(str))),
        fraction=("fraction", lambda x: ",".join(x.astype(str))),
    )

    return robust_cluster_subject


def add_q_idx_column(df, q_idx):
    # Add q_idx column to df and move it to the front
    df = df.assign(q_idx=q_idx)
    df.insert(0, "q_idx", df.pop("q_idx"))
    return df

# %%
# Load data
cluster_defs = {
    os.path.basename(f).split("_")[0]: f
    for f in glob.glob(CLUSTER_DIR + "/Q*metadata*.csv")
}
cluster_files = glob.glob(CLUSTER_DIR + "/Q*cluster*.csv")
cluster_files.sort()
recluster_files_all = glob.glob(RECLUSTER_DIR + "/Q*recluster*.tsv")

#
cluster_report = defaultdict(dict)
concatenated_cluster_def = []
concatenated_primary_cluster_df = []
concatenated_secondary_cluster_df = []
for cluster_file in cluster_files[:-1]:  # Skip last file (Q41)
    # Get associated question
    q_idx = os.path.basename(cluster_file).split("_")[0]
    # print(q_idx)
    question = questions_dict[q_idx]
    # print(f"{q_idx}: {question}")

    # Get associated cluster file
    cluster_df = pd.read_csv(cluster_file)
    assert cluster_df.shape[0] == len(utils.ALL_SUBJECT_IDS)

    cluster_df["iteration"] = 0
    # print(cluster_df.columns)
    is_two_level_clustering = (
        True if "top_level_cluster_id" in cluster_df.columns else False
    )
    # Is primary clustering non-exclusive?
    col_name = "top_level_cluster_id" if is_two_level_clustering else "cluster_ids"
    is_primary_non_exclusive = (
        cluster_df[col_name].fillna("").str.split(",").apply(len).max()
        > 1  # fillna("") is to handle NAs
    )

    # Get associated metadata
    cluster_def = pd.read_csv(cluster_defs[q_idx])

    concatenated_cluster_def.append(add_q_idx_column(cluster_def, q_idx))

    # Get associated recluster files and concatenate
    recluster_files = glob.glob(RECLUSTER_DIR + f"/{q_idx}*recluster*.tsv")
    recluster_files.sort()
    # print(recluster_files)
    cluster_reclusters_df = [cluster_df]
    for recluster_file in recluster_files:
        # print(recluster_file)
        recluster_df = pd.read_csv(recluster_file, sep="\t")
        assert recluster_df.shape[0] == len(utils.ALL_SUBJECT_IDS)

        recluster_df["iteration"] = int(
            os.path.basename(recluster_file).split("recluster")[1].split(".")[1]
        )
        cluster_reclusters_df.append(recluster_df)
    cluster_reclusters_df = pd.concat(cluster_reclusters_df)
    try:
        assert cluster_reclusters_df.shape[0] == cluster_df.shape[0] * (
            len(recluster_files) + 1
        )
    except AssertionError:
        print("Something wrong with recluster file number-of-rows")
        print(
            cluster_df.shape,
            [pd.read_csv(rf, sep="\t").shape for rf in recluster_files],
        )
        # print(cluster_reclusters_df.shape, cluster_df.shape)
        # print(cluster_reclusters_df.head())
        # raise AssertionError

    # Transform
    # If two-level clustering, rename "top_level_cluster_id" to "cluster_ids"
    if is_two_level_clustering:
        cluster_df.rename(columns={"top_level_cluster_id": "cluster_ids"}, inplace=True)
        cluster_reclusters_df.rename(
            columns={"top_level_cluster_id": "cluster_ids"}, inplace=True
        )

    # Check if population-specific question & subset
    specific_population = None
    for (
        population_name,
        population_questions,
    ) in utils.population_specific_question_ids.items():
        if q_idx in population_questions:
            specific_population = population_name
            break
    if specific_population is not None:
        cluster_df = cluster_df[
            cluster_df["subject_id"].isin(
                utils.population_subject_ids[specific_population]
            )
        ]
        assert cluster_df.shape[0] == len(
            utils.population_subject_ids[specific_population]
        )

        cluster_reclusters_df = cluster_reclusters_df[
            cluster_reclusters_df["subject_id"].isin(
                utils.population_subject_ids[specific_population]
            )
        ]
        assert cluster_reclusters_df.shape[0] == cluster_df.shape[0] * (
            len(recluster_files) + 1
        )

    # Process primary and secondary clusters
    exploded_primary_df = explode_cluster_ids(
        cluster_reclusters_df, column="cluster_ids"
    )
    primary_cluster_mean_stds = get_cluster_count_mean_stds(exploded_primary_df)
    robust_primary_clusters_df = get_robust_clusters(exploded_primary_df)
    robust_primary_clusters_df.rename(
        columns={"robust_cluster_ids": "cluster_ids"}, inplace=True
    )
    concatenated_primary_cluster_df.append(
        add_q_idx_column(robust_primary_clusters_df.reset_index(), q_idx)
    )
    if is_two_level_clustering:
        cluster_reclusters_df["secondary_cluster_ids"].fillna("", inplace=True)
        exploded_secondary_df = explode_cluster_ids(
            cluster_reclusters_df, column="secondary_cluster_ids"
        )
        secondary_cluster_mean_stds = get_cluster_count_mean_stds(
            exploded_secondary_df, column="secondary_cluster_ids"
        )
        robust_secondary_clusters_df = get_robust_clusters(
            exploded_secondary_df, column="secondary_cluster_ids"
        )
        robust_secondary_clusters_df.rename(
            columns={"robust_cluster_ids": "secondary_cluster_ids"}, inplace=True
        )
        is_secondary_non_exclusive = (
            cluster_reclusters_df["secondary_cluster_ids"]
            .fillna("")
            .astype(str)  # Ensure all entries are strings
            .str.split(",")
            .apply(len)
            .max()
            > 1
        )
        concatenated_secondary_cluster_df.append(
            add_q_idx_column(robust_secondary_clusters_df.reset_index(), q_idx)
        )

    # Save to dict
    cluster_report[q_idx]["question"] = question
    cluster_report[q_idx]["specific_population"] = specific_population
    cluster_report[q_idx]["cluster_def"] = cluster_def
    cluster_report[q_idx]["cluster_df"] = cluster_df
    cluster_report[q_idx]["cluster_reclusters_df"] = cluster_reclusters_df
    cluster_report[q_idx]["primary_cluster_mean_stds"] = primary_cluster_mean_stds
    cluster_report[q_idx]["is_primary_non_exclusive"] = is_primary_non_exclusive
    cluster_report[q_idx]["robust_primary_clusters_df"] = robust_primary_clusters_df
    cluster_report[q_idx]["is_two_level_clustering"] = is_two_level_clustering
    cluster_report[q_idx]["secondary_cluster_mean_stds"] = (
        secondary_cluster_mean_stds if is_two_level_clustering else None
    )
    cluster_report[q_idx]["robust_secondary_clusters_df"] = (
        robust_secondary_clusters_df if is_two_level_clustering else None
    )
    cluster_report[q_idx]["is_secondary_non_exclusive"] = (
        is_secondary_non_exclusive if is_two_level_clustering else None
    )

    # Validation
    if specific_population in utils.population_subject_ids.keys():
        if (
            robust_primary_clusters_df.shape[0]
            != len(utils.population_subject_ids[specific_population])
            and specific_population is not None
        ):
            print(
                f"WARNING: {q_idx} has {robust_primary_clusters_df.shape[0]} subjects instead of {len(utils.population_subject_ids[specific_population])} [{specific_population}]"
            )
            # print(robust_primary_clusters_df.index.to_list())
            # print(robust_primary_clusters_df.head())
            print(
                "Robust clusters not found for subjects: ",
                set(utils.population_subject_ids[specific_population])
                - set(robust_primary_clusters_df.index.to_list()),
            )

    else:
        if robust_primary_clusters_df.shape[0] != len(utils.ALL_SUBJECT_IDS):
            print(
                f"WARNING: {q_idx} has {robust_primary_clusters_df.shape[0]} subjects instead of {len(utils.ALL_SUBJECT_IDS)}"
            )
            # print(robust_primary_clusters_df.head())
            print(
                "Robust clusters not found for subjects: ",
                set(utils.ALL_SUBJECT_IDS)
                - set(robust_primary_clusters_df.index.to_list()),
            )

# Done processing all questions -- save to files
pd.concat(concatenated_cluster_def).to_csv(OUTPUT_CLUSTER_DEFS_FILE, index=False)
pd.concat(concatenated_primary_cluster_df).to_csv(
    OUTPUT_ROBUST_CLUSTERS_PRIMARY_FILE, index=False
)
pd.concat(concatenated_secondary_cluster_df).to_csv(
    OUTPUT_ROBUST_CLUSTERS_SECONDARY_FILE, index=False
)
print("Saved cluster definitions and robust cluster assignments...")

print(q_idx, question)
print()
print(cluster_df)
# print(primary_cluster_mean_stds)
print()
# print(cluster_def)
# robust_primary_clusters_df.reset_index()
# cluster_def
# Out:
# WARNING: Q13 has 92 subjects instead of 93
# Robust clusters not found for subjects:  {'C065'}
# WARNING: Q18 has 91 subjects instead of 93
# Robust clusters not found for subjects:  {'C060', 'C008'}
# WARNING: Q23 has 92 subjects instead of 93
# Robust clusters not found for subjects:  {'C084'}
# WARNING: Q25 has 91 subjects instead of 93
# Robust clusters not found for subjects:  {'C095', 'C064'}
# WARNING: Q30 has 72 subjects instead of 73 [nonstudents]
# Robust clusters not found for subjects:  {'C041'}
# WARNING: Q32 has 89 subjects instead of 93
# Robust clusters not found for subjects:  {'C002', 'C093', 'C073', 'C056'}
# WARNING: Q33 has 92 subjects instead of 93
# Robust clusters not found for subjects:  {'C072'}
# Saved cluster definitions and robust cluster assignments...
# Q40 If student or trainee, do you agree with your school's policies regarding medical students' roles at this time?
#
#    subject_id cluster_ids secondary_cluster_ids  iteration
# 3        C004          C3                  C3.1          0
# 5        C006          C1                  C1.1          0
# 6        C007          C1                  C1.3          0
# 7        C008          C2                  C2.1          0
# 22       C024          C1                  C1.1          0
# 23       C025          C1                  C1.1          0
# 27       C030          C4                  C4.3          0
# 29       C032          C1                  C1.1          0
# 32       C035          C1                  C1.1          0
# 33       C036          C1                  C1.1          0
# 34       C037          C2                  C2.1          0
# 49       C052          C4                  C4.3          0
# 66       C071          C2                  C2.2          0
# 67       C072          C1                  C1.1          0
# 78       C084          C4                  C4.3          0
# 84       C094          C1                  C1.1          0
# 85       C095          C2                  C2.1          0
# 90       C100          C3                  C3.1          0
# 91       C101          C1                  C1.3          0
# 92       C102          C3                  C3.1          0

# %%
# DEBUG
# Group by subject_id and iteration to get a list of cluster_ids for each subject_id and iteration
# grouped_grouped_df = (
#     exploded_primary_df.groupby(["subject_id", "iteration"])["cluster_ids"]
#     .agg(list)
#     .reset_index()
#     .groupby("subject_id")["cluster_ids"]
#     .agg(list)
#     .reset_index()
# )
# print(grouped_grouped_df)
# print(get_robust_clusters(exploded_primary_df))
# print(cluster_df)

# secondary_cluster_mean_stds = get_cluster_count_mean_stds(exploded_secondary_df)
# exploded_secondary_df
# cluster_reclusters_df
# exploded_secondary_df
# robust_secondary_clusters_df

# DEBUG
# for q_idx, q_data in cluster_report.items():
#     if q_data["is_two_level_clustering"]:
#         is_secondary_non_exclusive = q_data["is_secondary_non_exclusive"]
#         if is_secondary_non_exclusive:
#             print(q_idx, q_data["question"])
#             cluster_reclusters_df = q_data["cluster_reclusters_df"]
#             rows_with_nonexclusive_secondary_clusters = cluster_reclusters_df[
#                 cluster_reclusters_df["secondary_cluster_ids"]
#                 .fillna("")
#                 .astype(str)  # Ensure all entries are strings
#                 .str.split(",")
#                 .apply(len)
#                 > 1
#             ]
#             print(rows_with_nonexclusive_secondary_clusters)

# %%
## Make a text report of the clusters
def print_cluster_report(q_idx, q_data):
    question = q_data["question"]
    specific_population = q_data["specific_population"]
    if specific_population is not None:
        header_suffix = f" [ONLY {specific_population}]"
    else:
        header_suffix = ""

    print(f"\nQuestion {q_idx} - {question} {header_suffix}")

    cluster_defs = q_data["cluster_def"]
    per_cluster_data = q_data["primary_cluster_mean_stds"]
    cluster_df = q_data["cluster_df"]

    total_subjects = cluster_df.shape[0]

    is_primary_non_exclusive = q_data["is_primary_non_exclusive"]
    title_suffix = ""
    if is_primary_non_exclusive:
        title_suffix = f" [non-exclusive membership]"

    total_reported_subjects = 0
    print(f"  Primary Clusters{title_suffix}:")
    for i, row in per_cluster_data.iterrows():
        cluster_id = row["cluster_ids"]
        count_mean = int(row["count_mean"])
        count_std = round(row["count_std"], 2)
        total_reported_subjects += count_mean

        cluster_name = cluster_defs[cluster_defs["cluster_id"] == cluster_id][
            "cluster_name"
        ].values[0]
        cluster_desc = cluster_defs[cluster_defs["cluster_id"] == cluster_id][
            "cluster_description"
        ].values[0]

        print(
            f"    [{cluster_id}] {cluster_name}: {count_mean} +/- {count_std} s.d. out of {total_subjects} subjects ({100*count_mean/total_subjects:.2f}%) [{cluster_desc}]"  # -- {count_mean}/{total_subjects} subject(s) ({100*count_mean/total_subjects:.2f}%)
        )
    print(
        f"    Total # subjects across all Primary clusters: {total_reported_subjects} out of {total_subjects} subjects ignoring s.d."
    )

    # secondary clusters
    if q_data["is_two_level_clustering"]:
        try:
            cluster_df = q_data["cluster_df"]
            if cluster_df["secondary_cluster_ids"].isna().sum() == cluster_df.shape[0]:
                # print("No secondary clusters")
                return
            # print(cluster_df)

            cluster_reclusters_df = q_data["cluster_reclusters_df"]
            # print(cluster_reclusters_df)

            cluster_def = q_data["cluster_def"]
            # print(cluster_def)
            # print(cluster_def.shape)

            per_cluster_data = q_data["secondary_cluster_mean_stds"]
            # print(per_cluster_data)

            is_secondary_non_exclusive = q_data["is_secondary_non_exclusive"]
            title_suffix = ""
            if is_secondary_non_exclusive:
                title_suffix = f" [non-exclusive membership]"

            print(f"  Secondary Clusters{title_suffix}:")
            for i, row in per_cluster_data.iterrows():
                try:
                    cluster_id = row["secondary_cluster_ids"]
                    if (
                        cluster_id == ""
                        or cluster_id is None
                        or cluster_id == "nan"
                        or cluster_id == "None"
                        or cluster_id == "N/A"
                        or cluster_id == "NA"
                        or cluster_id == "--"
                        or cluster_id == "Not available"
                        # or cluster_id.isna()
                    ):
                        continue
                    count_mean = int(row["count_mean"])
                    count_std = round(row["count_std"], 2)

                    cluster_name = cluster_defs[
                        cluster_defs["cluster_id"] == cluster_id
                    ]["cluster_name"].values[0]
                    cluster_desc = cluster_defs[
                        cluster_defs["cluster_id"] == cluster_id
                    ]["cluster_description"].values[0]

                    print(
                        f"    [{cluster_id}] {cluster_name}: {count_mean} +/- {count_std} s.d. out of {total_subjects} subjects ({100*count_mean/total_subjects:.2f}%) [{cluster_desc}]"  # -- {count_mean}/{total_subjects} subject(s) ({100*count_mean/total_subjects:.2f}%)
                    )
                except Exception as e:
                    print(e, f"[{cluster_id}]")
                    # print(f"Missing data for cluster: [{cluster_id}]")
        except Exception as e:
            print(e, q_idx)
            print(f"Exception for question {q_idx}")


for q_idx, q_data in cluster_report.items():
    print_cluster_report(q_idx, q_data)


# Save STDOUT to cluster_report.txt
def print_report_to_file(filename):
    original_stdout = sys.stdout  # Save a reference to the original standard output

    with open(filename, "w") as f:
        sys.stdout = f  # Change the standard output to the file we created.
        for q_idx, q_data in cluster_report.items():
            print_cluster_report(q_idx, q_data)
        sys.stdout = original_stdout  # Reset the standard output to its original value


print_report_to_file(OUTPUT_REPORT_FILE)
# Out:
# Question Q00 - How old are you?
#   Primary Clusters:
#     [C1] Young Adults (22-33): 37 +/- 0.0 s.d. out of 93 subjects (39.78%) [Subjects who are between 22 and 33 years old]
#     [C2] Middle-aged Adults (34-45): 30 +/- 0.0 s.d. out of 93 subjects (32.26%) [Subjects who are between 34 and 45 years old]
#     [C3] Older Adults (46-60): 15 +/- 0.0 s.d. out of 93 subjects (16.13%) [Subjects who are between 46 and 60 years old]
#     [C4] Seniors (61 and above): 5 +/- 0.0 s.d. out of 93 subjects (5.38%) [Subjects who are 61 years old or above]
#     [C5] Unclear/irrelevant/no response: 6 +/- 0.0 s.d. out of 93 subjects (6.45%) [Subjects who have not provided their age or their response was unclear or irrelevant]
#     Total # subjects across all Primary clusters: 93 out of 93 subjects ignoring s.d.
#
# Question Q01 - Where do you live?
#   Primary Clusters:
#     [C1] Houston, Texas: 41 +/- 0.45 s.d. out of 93 subjects (44.09%) [Subjects reporting their location in Houston, Texas, regardless of specific neighborhood.]
#     [C2] San Antonio, Texas: 6 +/- 0.0 s.d. out of 93 subjects (6.45%) [Subjects reporting their location in San Antonio, Texas.]
#     [C3] Texas (Other): 14 +/- 0.0 s.d. out of 93 subjects (15.05%) [Subjects reporting locations in Texas other than Houston or San Antonio, or general responses indicating they live in Texas without specifying city.]
#     [C4] Florida: 10 +/- 0.0 s.d. out of 93 subjects (10.75%) [Subjects reporting their location in Florida]
#     [C5] Mid-West US: 13 +/- 0.45 s.d. out of 93 subjects (13.98%) [Subjects reporting their location in Mid-Western US states]
#     [C6] US (Other): 5 +/- 0.45 s.d. out of 93 subjects (5.38%) [Subjects reporting their location in the US, outside of Texas and Florida or those situated in the US but not specifying state or city.]
#     [C7] Unclear/Excluded/No response: 2 +/- 0.45 s.d. out of 93 subjects (2.15%) [Subjects whose location is unclear, outside the defined clusters, or that did not respond to the question.]
#     Total # subjects across all Primary clusters: 91 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Houston, Texas direct: 35 +/- 0.45 s.d. out of 93 subjects (37.63%) [Houston, Texas explicitly mentioned.]
#     [C1.2] Houston, Texas neighborhood: 5 +/- 0.55 s.d. out of 93 subjects (5.38%) [Subjects reporting a location within Houston, Texas but referencing specific neighborhoods or zip codes. ]
#     [C1.3] Houston, Texas multi-location: 2 +/- 0.71 s.d. out of 93 subjects (2.15%) [Subjects reporting multiple locations including Houston, Texas]
#
# Question Q02 - What is your marital status?
#   Primary Clusters:
#     [C1] Not currently married: 39 +/- 0.0 s.d. out of 93 subjects (41.94%) [Subjects not in a marriage]
#     [C2] Married currently: 49 +/- 0.0 s.d. out of 93 subjects (52.69%) [Subjects in a marriage]
#     [C3] Unclear/Excluded/No response: 5 +/- 0.0 s.d. out of 93 subjects (5.38%) [Subjects with unclear, excluded, or no responses]
#     Total # subjects across all Primary clusters: 93 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Single: 32 +/- 1.95 s.d. out of 93 subjects (34.41%) [Subjects who stated they are single]
#     [C1.2] Divorced: 3 +/- 0.0 s.d. out of 93 subjects (3.23%) [Subjects who stated they are divorced]
#     [C1.3] Widowed: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Subjects who stated they are widowed]
#     [C1.4] In a relationship: 4 +/- 0.0 s.d. out of 93 subjects (4.30%) [Subjects who are single but in a relationship]
#     [C2.1] Formally Married: 49 +/- 0.0 s.d. out of 93 subjects (52.69%) [Subjects who stated they are formally married]
#     [C3.1] No response: 3 +/- 0.0 s.d. out of 93 subjects (3.23%) [Subjects who did not respond]
#     [C3.2] Unclear response: 2 +/- 0.0 s.d. out of 93 subjects (2.15%) [Subjects with unclear responses]
#
# Question Q03 - Do you have kids?
#   Primary Clusters:
#     [C1] Parents: 48 +/- 0.0 s.d. out of 93 subjects (51.61%) [Subjects who have responded affirmatively to having kids]
#     [C2] Non-parents: 42 +/- 0.0 s.d. out of 93 subjects (45.16%) [Subjects who have responded negatively to not having kids]
#     [C3] Excluded: 3 +/- 0.0 s.d. out of 93 subjects (3.23%) [Subjects who provided unclear, irrelevant, or no responses]
#     Total # subjects across all Primary clusters: 93 out of 93 subjects ignoring s.d.
#
# Question Q04 - If you do have kids, provide details
#   Primary Clusters [non-exclusive membership]:
#     [C1] No Information: 46 +/- 0.0 s.d. out of 93 subjects (49.46%) [Subjects which provided unclear, irrelevant, or no responses.]
#     [C2] Single Child: 10 +/- 0.55 s.d. out of 93 subjects (10.75%) [Subjects which have one child.]
#     [C3] Two Children: 24 +/- 0.84 s.d. out of 93 subjects (25.81%) [Subjects which have two children.]
#     [C4] Three Children: 8 +/- 0.89 s.d. out of 93 subjects (8.60%) [Subjects which have three children.]
#     [C5] Four or more Children: 3 +/- 0.0 s.d. out of 93 subjects (3.23%) [Subjects which have four or more children.]
#     [C6] Child Age Provided: 33 +/- 2.88 s.d. out of 93 subjects (35.48%) [Subjects which provided the ages of their children.]
#     [C7] Child Age Not Provided: 7 +/- 2.95 s.d. out of 93 subjects (7.53%) [Subjects didn't provide the ages of their children.]
#     [C8] Children Living at Home: 19 +/- 10.4 s.d. out of 93 subjects (20.43%) [Subjects which still have children living at home.]
#     [C9] Children No Longer Living at Home: 9 +/- 1.79 s.d. out of 93 subjects (9.68%) [Subjects which no longer have children living at home.]
#     Total # subjects across all Primary clusters: 159 out of 93 subjects ignoring s.d.
#
# Question Q05 - Are you a caretaker otherwise? (if not own kids, eg elderly parents, adopted family member, etc)
#   Primary Clusters:
#     [C1] Caretakers of Family Members: 14 +/- 1.52 s.d. out of 93 subjects (15.05%) [Subjects who responded that they take care of relatives (elderly parents, children, siblings or others).]
#     [C2] Caretakers of Animals: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Subjects who take care of animals.]
#     [C3] Partial Caretakers: 4 +/- 1.3 s.d. out of 93 subjects (4.30%) [Subjects who participate in caretaking but not as primary caretakers.]
#     [C4] Financially Supportive: 1 +/- 0.55 s.d. out of 93 subjects (1.08%) [Subjects who provide financial support instead of physical caretaking.]
#     [C5] No Caretaking Responsibilities: 70 +/- 1.3 s.d. out of 93 subjects (75.27%) [Subjects who stated that they do not take care of anyone.]
#     [C6] Excluded: 1 +/- 0.89 s.d. out of 93 subjects (1.08%) [Responses that are unclear, irrelevant, or did not provide a response to the question.]
#     Total # subjects across all Primary clusters: 91 out of 93 subjects ignoring s.d.
#
# Question Q06 - What type of healthcare professional or student/trainee are you?
#   Primary Clusters [non-exclusive membership]:
#     [C1] Physicians: 51 +/- 1.73 s.d. out of 93 subjects (54.84%) [Healthcare professionals specialized in general medicine or specific field such as cardiology, psychiatry, emergency medicine, infectious diseases, etc.]
#     [C2] Medical Students: 20 +/- 0.45 s.d. out of 93 subjects (21.51%) [Individuals who are studying medicine.]
#     [C3] Nurses: 8 +/- 0.0 s.d. out of 93 subjects (8.60%) [Healthcare professionals specialized in nursing.]
#     [C4] Healthcare Professionals: 12 +/- 2.59 s.d. out of 93 subjects (12.90%) [General category for healthcare professionals not specifically categorized into doctors, nurses, or students.]
#     [C5] Residents: 7 +/- 0.89 s.d. out of 93 subjects (7.53%) [Healthcare professionals who are in residency training period.]
#     [C6] Excluded: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Participants who provided unclear, irrelevant, or no response.]
#     Total # subjects across all Primary clusters: 99 out of 93 subjects ignoring s.d.
#
# Question Q07 - If student or trainee, what year are you in?  [ONLY students]
#   Primary Clusters:
#     [C1] First Year: 4 +/- 0.0 s.d. out of 20 subjects (20.00%) [Subjects who are in the First Year of their studies/training.]
#     [C2] Second Year: 8 +/- 0.0 s.d. out of 20 subjects (40.00%) [Subjects who are in the Second Year of their studies/training.]
#     [C3] Third Year: 5 +/- 0.0 s.d. out of 20 subjects (25.00%) [Subjects who are in the Third Year of their studies/training.]
#     [C4] Fourth Year: 2 +/- 0.0 s.d. out of 20 subjects (10.00%) [Subjects who are in the Fourth Year of their studies/training.]
#     [C6] Excluded: 1 +/- 0.0 s.d. out of 20 subjects (5.00%) [Subjects who did not provide a response or whose responses are irrelevant or unclear.]
#     Total # subjects across all Primary clusters: 20 out of 20 subjects ignoring s.d.
#
# Question Q08 - What institution did you complete your (or are currently) training at?
#   Primary Clusters [non-exclusive membership]:
#     [C1] Baylor College of Medicine: 23 +/- 0.71 s.d. out of 93 subjects (24.73%) [Responses indicating training at Baylor College of Medicine]
#     [C2] University of Texas: 13 +/- 2.88 s.d. out of 93 subjects (13.98%) [Responses indicating training at any of the University of Texas's institutions]
#     [C3] Texas Institutions: 23 +/- 6.2 s.d. out of 93 subjects (24.73%) [Responses indicating training at a variety of Texas institutions]
#     [C4] Multiple Institutions: 39 +/- 7.4 s.d. out of 93 subjects (41.94%) [Responses indicating training at multiple, diverse institutions]
#     [C5] Out of US Training: 17 +/- 2.49 s.d. out of 93 subjects (18.28%) [Responses indicating training at institutions outside the US]
#     [C6] Unspecified or Missing Information: 3 +/- 0.45 s.d. out of 93 subjects (3.23%) [Responses that are unclear, irrelevant, or have no response]
#     Total # subjects across all Primary clusters: 118 out of 93 subjects ignoring s.d.
#
# Question Q09 - If you are a physician, did you train in the US at any point?  [ONLY physicians]
#   Primary Clusters:
#     [C1] Trained in US: 49 +/- 0.0 s.d. out of 54 subjects (90.74%) [Subjects trained as a physician in the US]
#     [C2] Did not train in US: 1 +/- 0.0 s.d. out of 54 subjects (1.85%) [Subjects did not train as a physician in the US]
#     [C3] No clear response: 4 +/- 0.0 s.d. out of 54 subjects (7.41%) [Subjects that provided unclear, irrelevant, or no responses]
#     Total # subjects across all Primary clusters: 54 out of 54 subjects ignoring s.d.
#
# Question Q10 - What is your specialty (if student, what specialty are you thinking of)?
#   Primary Clusters [non-exclusive membership]:
#     [C1] Cardiology/Respiratory: 4 +/- 0.0 s.d. out of 93 subjects (4.30%) [Subjects that mentioned Cardiology, Respiratory therapy or related fields.]
#     [C10] OBGYN: 2 +/- 0.0 s.d. out of 93 subjects (2.15%) [Subjects who mentioned Obstetrics and Gynaecology.]
#     [C11] Infectious Diseases: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Subjects who specialize in Infectious Diseases.]
#     [C12] Anesthesiology and Critical Care: 2 +/- 0.55 s.d. out of 93 subjects (2.15%) [Subjects who are in the field of Anesthesiology and Critical Care.]
#     [C13] Surgery/ER: 5 +/- 1.34 s.d. out of 93 subjects (5.38%) [Subjects who are in the field of Surgery or the Emergency Room.]
#     [C14] Internal Medicine: 11 +/- 0.45 s.d. out of 93 subjects (11.83%) [Subjects who mentioned they specialize or are considering the field of Internal Medicine.]
#     [C15] Pathology: 3 +/- 0.0 s.d. out of 93 subjects (3.23%) [Subjects who are in the field of Pathology.]
#     [C16] Excluded: 2 +/- 0.45 s.d. out of 93 subjects (2.15%) [Subjects who provided unclear, irrelevant, or no responses.]
#     [C2] Neurology/Neurocritical Care: 5 +/- 0.0 s.d. out of 93 subjects (5.38%) [Subjects who considered or are specializing in Neurology or Neurocritical care.]
#     [C3] Pediatrics: 5 +/- 0.0 s.d. out of 93 subjects (5.38%) [Subjects who are working or considering Pediatrics.]
#     [C4] Head and neck surgery/Related Surgery: 1 +/- 0.45 s.d. out of 93 subjects (1.08%) [Subjects who mentioned Head and neck surgery or related surgery specialties.]
#     [C5] Fertility: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Subjects who specializes in Fertility.]
#     [C6] Psychiatry: 15 +/- 0.0 s.d. out of 93 subjects (16.13%) [Subjects who are in the field of Psychiatry.]
#     [C7] Emergency Medicine: 25 +/- 1.52 s.d. out of 93 subjects (26.88%) [Subjects who are in the field of Emergency Medicine.]
#     [C8] Pulmonary Critical Care: 15 +/- 0.84 s.d. out of 93 subjects (16.13%) [Subjects who are in the field of Pulmonary Critical Care.]
#     [C9] Oncology: 2 +/- 0.0 s.d. out of 93 subjects (2.15%) [Subjects who mentioned Oncology or related fields.]
#     Total # subjects across all Primary clusters: 99 out of 93 subjects ignoring s.d.
#
# Question Q11 - How long have you been practicing?  [ONLY nonstudents]
#   Primary Clusters:
#     [C1] Years under 15: 52 +/- 1.52 s.d. out of 73 subjects (71.23%) [Subjects who have been practicing for under 15 years.]
#     [C2] Years 15-30: 15 +/- 1.64 s.d. out of 73 subjects (20.55%) [Subjects who have been practicing between 15 and 30 years.]
#     [C3] Years over 30: 4 +/- 0.55 s.d. out of 73 subjects (5.48%) [Subjects who have been practicing for over 30 years.]
#     [C4] Excluded: 1 +/- 0.0 s.d. out of 73 subjects (1.37%) [Subjects that provided unclear, irrelevant, or no responses.]
#     Total # subjects across all Primary clusters: 72 out of 73 subjects ignoring s.d.
#
# Question Q12 - Over the past two months, have you practiced clinically in areas where you could be in touch with patients who have covid-19?  [ONLY nonstudents]
#   Primary Clusters:
#     [C1] COVID-19 Patient Contact: 72 +/- 0.0 s.d. out of 73 subjects (98.63%) [Subjects reported professional contact with patients who have COVID-19]
#     [C2] No COVID-19 Patient Contact: 1 +/- 0.0 s.d. out of 73 subjects (1.37%) [Subjects reported no professional contact with patients who have COVID-19]
#     Total # subjects across all Primary clusters: 73 out of 73 subjects ignoring s.d.
#
# Question Q13 - Are you concerned about your safety, and how?
#   Primary Clusters [non-exclusive membership]:
#     [C1] Safety concern due to exposure risk: 63 +/- 1.52 s.d. out of 93 subjects (67.74%) [Subjects voice concerns about getting infected or exposing others to infection due to their workplace environment or lack of adequate protection]
#     [C2] Confidence in precautions or PPE: 13 +/- 1.64 s.d. out of 93 subjects (13.98%) [Subjects feel safe due to personal protective equipment or precautions they have taken/at their workplace]
#     [C3] Unconcerned about safety: 26 +/- 1.41 s.d. out of 93 subjects (27.96%) [Subjects expressed no concern about their safety]
#     [C4] Limited PPE concerns: 18 +/- 0.89 s.d. out of 93 subjects (19.35%) [Subjects express concerns regarding the shortage or inadequacy of personal protective equipment]
#     [C5] Excluded: 2 +/- nan s.d. out of 93 subjects (2.15%) [Responses are unclear, irrelevant, or not provided]
#     Total # subjects across all Primary clusters: 122 out of 93 subjects ignoring s.d.
#
# Question Q14 - Are you concerned about safety of loved ones, and how?
#   Primary Clusters:
#     [C1] Yes: 86 +/- 0.0 s.d. out of 93 subjects (92.47%) [Subjects have positively communicated concerns about loved ones' safety.]
#     [C2] No: 7 +/- 0.0 s.d. out of 93 subjects (7.53%) [Subjects have negatively responded, indicating no concerns about loved ones' safety.]
#     Total # subjects across all Primary clusters: 93 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Concerned about transmission: 44 +/- 6.02 s.d. out of 93 subjects (47.31%) [Subjects expressing concern about transmitting the virus to their loved ones.]
#     [C1.2] Concerned about specific family members: 45 +/- 6.42 s.d. out of 93 subjects (48.39%) [Subjects concerned about specific family members (e.g., parents, grandparents, children, spouse).]
#     [C1.3] Concerned for family members in healthcare: 5 +/- 0.45 s.d. out of 93 subjects (5.38%) [Subjects express concern about family members who are involved in healthcare.]
#     [C1.4] General Concern: 15 +/- 2.07 s.d. out of 93 subjects (16.13%) [Subjects expressed concern for loved ones without providing specific details.]
#
# Question Q15 - Have you modified your routine to protect yourself or others, and how?
#   Primary Clusters [non-exclusive membership]:
#     [C1] Self-care and hygiene: 51 +/- 15.83 s.d. out of 93 subjects (54.84%) [Adopting leading hygiene practices such as increasing frequency of handwashing, use of sanitizer, changing of clothes, frequent showers, and decontamination to reduce exposure risk.]
#     [C2] Use of Personal Protective Equipment (PPE): 32 +/- 8.07 s.d. out of 93 subjects (34.41%) [Increased use of PPE like masks, gloves, scrubs or gowns, both during work times and while being in public places.]
#     [C3] Limiting travel and outings: 26 +/- 5.34 s.d. out of 93 subjects (27.96%) [Decreased frequency of travel including public transport usage, avoiding unnecessary trips, restricting visits to the grocery store, and avoiding social gathering places like the gym.]
#     [C4] Increased use of virtual methods for activities: 7 +/- 1.1 s.d. out of 93 subjects (7.53%) [Preference for remote methods in work and personal life, like telemedicine practice, remote work, online shopping, etc. to decrease physical contact and risk of transmission.]
#     [C5] Social distancing within households and increased isolation practices: 22 +/- 3.35 s.d. out of 93 subjects (23.66%) [Modified routines to include physical distancing from family members or roommates; in some cases, even self-isolation after shifts, quarantining after exposure, or changing living arrangements.]
#     [C6] Routine changes specific to workplace: 14 +/- 5.5 s.d. out of 93 subjects (15.05%) [Frequent changes of scrubs at the workplace, wearing hospital scrubs, changing into street clothes before leaving, etc.]
#     [C7] Vague responses: 7 +/- 0.84 s.d. out of 93 subjects (7.53%) [Participants have responded affirmatively to modifying their routines, but have given no details regarding the specific changes made.]
#     [C8] Entry and exit practices: 32 +/- 4.27 s.d. out of 93 subjects (34.41%) [Adopting a routine upon arriving and leaving the workplace or home including changing clothes, immediate showers, and sanitizing belongings.]
#     Total # subjects across all Primary clusters: 191 out of 93 subjects ignoring s.d.
#
# Question Q16 - Has this crisis taken a toll on you physically in any way?
#   Primary Clusters:
#     [C1] Yes: 48 +/- 0.0 s.d. out of 93 subjects (51.61%) [Responses indicating a physical toll taken due to the crisis.]
#     [C2] No: 42 +/- 0.0 s.d. out of 93 subjects (45.16%) [Responses indicating no physical toll taken due to the crisis.]
#     [C3] Unclear/irrelevant/no response: 3 +/- 0.0 s.d. out of 93 subjects (3.23%) [Responses that are either unclear, irrelevant or no responses.]
#     Total # subjects across all Primary clusters: 93 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Increased workload and stress: 17 +/- 4.95 s.d. out of 93 subjects (18.28%) [Responses within the Yes cluster that mention an increase in workload leading to heightened stress levels and physical exhaustion.]
#     [C1.2] Limited activity/fitness: 17 +/- 0.0 s.d. out of 93 subjects (18.28%) [Responses within the Yes cluster talking about the limitation in physical activity due to gym closure or the crisis in general.]
#     [C1.3] Disturbed sleep: 19 +/- 1.41 s.d. out of 93 subjects (20.43%) [Responses within the Yes cluster that refer to disturbed or reduced sleep patterns.]
#     [C1.4] Dietary changes: 7 +/- 1.14 s.d. out of 93 subjects (7.53%) [Responses within the Yes cluster that discuss changes in diet or eating habits.]
#     [C1.5] General physical distress: 18 +/- 4.16 s.d. out of 93 subjects (19.35%) [Responses within the Yes cluster addressing general physical discomfort, fatigue or related health problems due to the crisis.]
#     [C2.1] Continued healthy lifestyle: 3 +/- 0.45 s.d. out of 93 subjects (3.23%) [Responses within the No cluster that mention continuous healthy lifestyle despite the crisis.]
#     [C2.2] Minimal physical impact: 35 +/- 0.71 s.d. out of 93 subjects (37.63%) [Responses within the No cluster that report no significant physical impact.]
#     [C2.3] Mental impact, not physical: 4 +/- 0.45 s.d. out of 93 subjects (4.30%) [Responses within the No cluster that specify mental health impact yet no physical consequence.]
#     [C3.1] Indirect Positive Effect: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Responses within the Unclear/irrelevant/no response cluster mentioning indirect positive effects of the crisis.]
#     [C3.2] Ambiguous Response: 2 +/- 0.0 s.d. out of 93 subjects (2.15%) [Responses within the Unclear/irrelevant/no response cluster that are ambiguous or do not clearly answer the question.]
#
# Question Q17 - How many hours are you working on average (per week) nowadays?
#   Primary Clusters:
#     [C1] Full-time (40 hr/week): 10 +/- 0.71 s.d. out of 93 subjects (10.75%) [Working exactly 40 hours per week.]
#     [C2] Less than Full-time (under 40 hr/week): 24 +/- 1.1 s.d. out of 93 subjects (25.81%) [Working less than 40 hours per week.]
#     [C3] More than Full-time (over 40 hr/week): 54 +/- 0.55 s.d. out of 93 subjects (58.06%) [Working more than 40 hours per week.]
#     [C4] Unclear/Excluded/No response: 4 +/- 1.52 s.d. out of 93 subjects (4.30%) [Working hours not stated or unclear.]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters:
#     [C1.1] Standard Full-time: 10 +/- 0.71 s.d. out of 93 subjects (10.75%) [Working exact 40 hours per week.]
#     [C2.1] Part-time Under 36 hours: 13 +/- 1.67 s.d. out of 93 subjects (13.98%) [Working less than 36 hours per week.]
#     [C2.2] Semi Full-time Between 36-39 hours: 10 +/- 1.34 s.d. out of 93 subjects (10.75%) [Working between 36-39 hours per week.]
#     [C3.1] Extended Full-time Between 41-60 hours: 29 +/- 0.89 s.d. out of 93 subjects (31.18%) [Working between 41-60 hours per week.]
#     [C3.2] Super Full-time 61 hours and above: 24 +/- 0.55 s.d. out of 93 subjects (25.81%) [Working 61 hours per week and above.]
#
# Question Q18 - How has your working schedule and logistics changed?
#   Primary Clusters:
#     [C1] Increased hours: 30 +/- 1.58 s.d. out of 93 subjects (32.26%) [Work hours have increased due to varying reasons such as increase in patient load, more administrative work, more meetings etc.]
#     [C2] Decreased hours: 24 +/- 0.71 s.d. out of 93 subjects (25.81%) [Work hours have decreased due to reasons like lowering patient volume, shift in work locations, reduction in shifts, less structured working hours, etc.]
#     [C3] No change: 20 +/- 1.0 s.d. out of 93 subjects (21.51%) [There has been no significant changes in the working hours. ]
#     [C4] Other: 14 +/- 1.67 s.d. out of 93 subjects (15.05%) [Change in working logistics or different patterns of work, changes in shifts, changes in location of work etc.]
#     [C5] Unclear/irrelevant/no response: 4 +/- 0.89 s.d. out of 93 subjects (4.30%) [Subject responses that are unclear, irrelevant or noncommunicative. ]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Increased hours due to patient load: 25 +/- 4.16 s.d. out of 93 subjects (26.88%) [In the increased hours cluster, these subjects reported an increased workload due to the rise in patients.]
#     [C1.2] Increased hours due to administrative work: 7 +/- 2.07 s.d. out of 93 subjects (7.53%) [Subjects in the increased hours cluster reporting rise in administrative duties leading to longer hours.]
#     [C2.1] Decreased hours due to shift changes: 21 +/- 1.79 s.d. out of 93 subjects (22.58%) [Subjects who experience decrease in work hours due to changes in shifts.]
#     [C2.2] Decreased hours due to work from home: 3 +/- 2.3 s.d. out of 93 subjects (3.23%) [Subjects who experience decrease in work hours due to shift in location of work to home.]
#     [C3.1] No significant changes but change in work logistics: 10 +/- 4.16 s.d. out of 93 subjects (10.75%) [Subjects who, although experiencing no significant changes in work hours, reported changes in work logistics.]
#     [C4.1] Changes in shift timings/wave: 8 +/- 2.7 s.d. out of 93 subjects (8.60%) [Subjects who reported changes in shift timings or patterns.]
#     [C4.2] Changes in Work Locations: 7 +/- 5.03 s.d. out of 93 subjects (7.53%) [Subjects reporting a change in the physical location of their work.]
#
# Question Q19 - How do your working hours compare to pre-covid-19 crisis?
#   Primary Clusters:
#     [C1] Increased hours: 24 +/- 0.84 s.d. out of 93 subjects (25.81%) [Responses indicating an increase in working hours compared to before the COVID-19 crisis.]
#     [C2] Decreased hours: 29 +/- 0.55 s.d. out of 93 subjects (31.18%) [Responses indicating a decrease in working hours since the COVID-19 crisis began.]
#     [C3] No change: 32 +/- 1.92 s.d. out of 93 subjects (34.41%) [Responses indicating that there has been little or no change in working hours.]
#     [C4] Other: 5 +/- 2.22 s.d. out of 93 subjects (5.38%) [Responses that don't belong in the first three categories but still contains info.]
#     [C5] Unclear/irrelevant/no response: 2 +/- 0.45 s.d. out of 93 subjects (2.15%) [Responses that do not include a clear comparison of pre-crisis and current working hours.]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Minor increment in hours: 13 +/- 3.27 s.d. out of 93 subjects (13.98%) [Responses indicating a small or slight increase in working hours]
#     [C1.2] Major increment in hours: 9 +/- 1.67 s.d. out of 93 subjects (9.68%) [Responses mentioning a significant increase in working hours]
#     [C2.1] Minor reduction in hours: 15 +/- 2.19 s.d. out of 93 subjects (16.13%) [Responses indicating a small or slight decrease in working hours]
#     [C2.2] Major reduction in hours: 12 +/- 2.07 s.d. out of 93 subjects (12.90%) [Responses mentioning a significant decrease in working hours]
#     [C3] No change: 22 +/- nan s.d. out of 93 subjects (23.66%) [Responses indicating that there has been little or no change in working hours.]
#     [C3.1] Same, but different distribution: 8 +/- 1.64 s.d. out of 93 subjects (8.60%) [Responses similar to "no change", but with changes in work distribution or format ]
#     [C4] Other: 1 +/- nan s.d. out of 93 subjects (1.08%) [Responses that don't belong in the first three categories but still contains info.]
#     [C4.1] Increased workload: 3 +/- 2.07 s.d. out of 93 subjects (3.23%) [Responses indicating an increase in workload, not necessarily hours.]
#     [C4.2] Decreased efficiency or focus: 2 +/- 0.0 s.d. out of 93 subjects (2.15%) [Responses indicating decrease in effectiveness or focus in work/study]
#     [C5] Unclear/irrelevant/no response: 2 +/- nan s.d. out of 93 subjects (2.15%) [Responses that do not include a clear comparison of pre-crisis and current working hours.]
#
# Question Q20 - How do think the covid-19 crisis has affected the quality of patient care?
#   Primary Clusters:
#     [C1] Better: 6 +/- 1.14 s.d. out of 93 subjects (6.45%) [Impacted positively or believes that the quality of care has improved or remained good.]
#     [C2] Worse: 55 +/- 1.0 s.d. out of 93 subjects (59.14%) [Patient care negatively affected due to various factors.]
#     [C3] No-change: 14 +/- 0.45 s.d. out of 93 subjects (15.05%) [Believe that there has been no significant change in the quality of patient care.]
#     [C4] Other: 13 +/- 1.79 s.d. out of 93 subjects (13.98%) [Responses that do not fall into better, worse, or no-change categories but state other effects.]
#     [C5] Unclear/irrelevant/no response: 3 +/- 0.0 s.d. out of 93 subjects (3.23%) [Non-responses or responses that are too vague or irrelevant to form definite conclusions.]
#     Total # subjects across all Primary clusters: 91 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Improved for COVID patients: 2 +/- 0.55 s.d. out of 93 subjects (2.15%) [Care quality particularly improved for COVID-19 patients.]
#     [C1.2] Better procedures: 1 +/- 0.58 s.d. out of 93 subjects (1.08%) [Heightened precautions, cleanliness and hygiene have led to better patient care.]
#     [C1.3] Increase via Telehealth: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Improved patient care through increased accessibility via telehealth measures.]
#     [C2.1] Increased workload: 7 +/- 3.58 s.d. out of 93 subjects (7.53%) [Negative impact due to handling more cases and overworked healthcare providers.]
#     [C2.2] Telehealth disadvantages: 11 +/- 3.96 s.d. out of 93 subjects (11.83%) [Telehealth measures and lack of physical examinations negatively impacting patient care.]
#     [C2.3] Resource shortage: 6 +/- 1.92 s.d. out of 93 subjects (6.45%) [Shortage of resources, including PPE and healthcare services led to compromised care.]
#     [C2.4] Less face-to-face time: 11 +/- 3.19 s.d. out of 93 subjects (11.83%) [Diminished quality of care as a result of less face-to-face time or physical interaction with patients.]
#     [C2.5] Less focus on non-COVID: 10 +/- 3.74 s.d. out of 93 subjects (10.75%) [Impacted negatively due to shift in focus to COVID-19 patients and neglect of patients with other health issues.]
#     [C2.6] Change in procedures: 7 +/- 2.86 s.d. out of 93 subjects (7.53%) [Changes in normal procedures negatively impacting patient care.]
#     [C2.7] No visitor policies: 3 +/- 0.89 s.d. out of 93 subjects (3.23%) [Negative impact on patient care due to no visitor policies.]
#     [C3.1] Maintained practices: 5 +/- 5.68 s.d. out of 93 subjects (5.38%) [Patient care is unaffected due to maintained normal practices or procedures.]
#     [C3.2] Unaffected at Institution: 3 +/- 1.0 s.d. out of 93 subjects (3.23%) [The quality of patient care has not been affected at their specific institution.]
#     [C4.1] Impact on outpatient care: 2 +/- 0.84 s.d. out of 93 subjects (2.15%) [Outpatient care specifically affected.]
#     [C4.2] Mix of impacts: 8 +/- 2.41 s.d. out of 93 subjects (8.60%) [Mixed effects with both positive and negative influences on patient care.]
#     [C4.3] Changes in Practices: 2 +/- 0.89 s.d. out of 93 subjects (2.15%) [Changes in medical practices as a response to the crisis.]
#
# Question Q21 - How has it changed your approach to management? (different from usual, at odds with existing guidelines, may not be as effective, etc.)  [ONLY nonstudents]
#   Primary Clusters:
#     [C1] Changed: 62 +/- 1.79 s.d. out of 73 subjects (84.93%) [Responses where the subjects reported that their management approach has changed due to the situation]
#     [C2] No change: 7 +/- 1.34 s.d. out of 73 subjects (9.59%) [Responses where the subjects reported that their management approach has not changed]
#     [C3] Fluctuating/uncertain change: 1 +/- 0.45 s.d. out of 73 subjects (1.37%) [Responses where the subjects reported fluctuating or uncertain changes in their management approach]
#     [C4] Unclear/irrelevant/no response: 2 +/- 0.0 s.d. out of 73 subjects (2.74%) [Responses where the subjects did not provide a clear answer or did not respond at all]
#     Total # subjects across all Primary clusters: 72 out of 73 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Increased use of technology: 17 +/- 1.14 s.d. out of 73 subjects (23.29%) [Responses where subjects reported increased use of telehealth, virtual visits, and technology in general due to the situation]
#     [C1.2] Limited patient interaction: 19 +/- 3.27 s.d. out of 73 subjects (26.03%) [Responses where subjects reported a decrease in physical engagement or direct interaction with patients]
#     [C1.3] Increased precaution while dealing with patients: 17 +/- 1.67 s.d. out of 73 subjects (23.29%) [Responses where subjects reported increased safety measures and precautions, like the use of PPE]
#     [C1.4] Changed treatment method due to COVID-19: 20 +/- 3.7 s.d. out of 73 subjects (27.40%) [Responses where subjects reported adjustments to treatments and procedures due to the virus]
#     [C1.5] Improved communication and patient education: 7 +/- 3.36 s.d. out of 73 subjects (9.59%) [Responses where subjects reported increased patient education or improved communication]
#     [C2.1] Continued in-person interaction despite risks: 2 +/- 0.89 s.d. out of 73 subjects (2.74%) [Responses where subjects reported that they still interact with their patients in person, despite the risks]
#     [C2.2] Added precautions, but management largely unchanged: 6 +/- 1.1 s.d. out of 73 subjects (8.22%) [Responses where subjects reported that while they have added precautions, their management approach is still largely the same]
#     [C3.1] Unsure: 1 +/- 0.45 s.d. out of 73 subjects (1.37%) [Responses where subjects expressed uncertainty regarding the change in their management approach]
#     [C4.1] No response/unclear: 2 +/- 1.34 s.d. out of 73 subjects (2.74%) [Responses where subjects either did not respond or gave unclear responses]
#
# Question Q22 - Are your processes different for end-of-life decisions? Do you have to take people off ventilator more frequently?  [ONLY nonstudents]
#   Primary Clusters:
#     [C1] Yes: 31 +/- 1.58 s.d. out of 73 subjects (42.47%) [Subjects reported changes in end-of-life decision and/or increased frequency of taking people off ventilator due to COVID-19.]
#     [C2] No: 30 +/- 1.58 s.d. out of 73 subjects (41.10%) [Subjects did not report changes in end-of-life decision or increase in frequency of taking people off ventilator.]
#     [C3] Unclear/irrelevant/no response: 12 +/- 0.0 s.d. out of 73 subjects (16.44%) [Subjects gave unclear responses, did not answer the question, or the question was not applicable.]
#     Total # subjects across all Primary clusters: 73 out of 73 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] End-of-life discussions with family: 14 +/- 3.32 s.d. out of 73 subjects (19.18%) [Subject mentioned changes in conduct of end-of-life conversations with patient's families.]
#     [C1.2] Patient ventilation status: 9 +/- 3.11 s.d. out of 73 subjects (12.33%) [Subject noted increase in frequency of taking patients off of ventilators.]
#     [C1.3] Visitor policies: 4 +/- 2.59 s.d. out of 73 subjects (5.48%) [Subject indicated changes in visitation policies impacting end-of-life decisions.]
#     [C2.1] Not applicable: 10 +/- 1.0 s.d. out of 73 subjects (13.70%) [Subject's specialty does not involve making end-of-life decisions or handling patients on ventilators.]
#     [C2.2] No Changes: 20 +/- 1.79 s.d. out of 73 subjects (27.40%) [Subject reported no changes in their processes.]
#     [C3.1] Unclear response: 1 +/- 0.0 s.d. out of 73 subjects (1.37%) [Responses were ambiguous or did not directly answer the question.]
#     [C3.2] No response: 11 +/- 0.0 s.d. out of 73 subjects (15.07%) [Subjects did not respond to the question.]
#     [C3.3] Not applicable: 1 +/- nan s.d. out of 73 subjects (1.37%) [The question was not applicable for the subject due to their professional specialty.]
#
# Question Q23 - How prepared do you feel for the COVID-19 pandemic on a personal level?
#   Primary Clusters:
#     [C1] Prepared: 68 +/- 1.64 s.d. out of 93 subjects (73.12%) [Subjects who feel prepared or have a positive sentiment towards their preparedness for the COVID-19 pandemic.]
#     [C2] Unprepared: 21 +/- 1.41 s.d. out of 93 subjects (22.58%) [Subjects who express feeling unprepared or have a negative sentiment towards their preparedness for the COVID-19 pandemic.]
#     [C3] Unclear/irrelevant/no response: 3 +/- 0.45 s.d. out of 93 subjects (3.23%) [Subjects who didn’t provide a clear response or where the response was not relevant to their preparedness assessment.]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1] Prepared: 3 +/- nan s.d. out of 93 subjects (3.23%) [Subjects who feel prepared or have a positive sentiment towards their preparedness for the COVID-19 pandemic.]
#     [C1.1] Knowledge and Experience: 47 +/- 9.21 s.d. out of 93 subjects (50.54%) [Subjects who feel prepared due to their knowledge, experience or training.]
#     [C1.2] Adaptibility: 35 +/- 5.43 s.d. out of 93 subjects (37.63%) [Subjects who feel prepared because they have been able to adapt to the changes and challenges presented by COVID-19.]
#     [C1.3] Equipment and Resources: 7 +/- 1.82 s.d. out of 93 subjects (7.53%) [Subjects who feel prepared due to having the necessary equipment or resources.]
#     [C2] Unprepared: 1 +/- nan s.d. out of 93 subjects (1.08%) [Subjects who express feeling unprepared or have a negative sentiment towards their preparedness for the COVID-19 pandemic.]
#     [C2.1] Lack of Knowledge: 12 +/- 7.16 s.d. out of 93 subjects (12.90%) [Subjects who feel unprepared due to lack of knowledge or information.]
#     [C2.2] Impact on Mental Health: 9 +/- 9.07 s.d. out of 93 subjects (9.68%) [Subjects who feel unprepared due to the impact on their mental health.]
#     [C2.3] Lack of Resources: 3 +/- 1.0 s.d. out of 93 subjects (3.23%) [Subjects who feel unprepared due to lack of equipment or resources.]
#     [C2.4] Lack of Support: 2 +/- 1.14 s.d. out of 93 subjects (2.15%) [Subjects who feel unprepared due to a lack of support.]
#     [C3.1] Neutral sentiments: 3 +/- 0.45 s.d. out of 93 subjects (3.23%) [Subjects with neutral sentiments towards their preparedness.]
#
# Question Q24 - How prepared do you feel the unit/hospital is for the COVID-19 pandemic?
#   Primary Clusters:
#     [C1] Prepared: 57 +/- 3.83 s.d. out of 93 subjects (61.29%) [Those who believe their hospital/unit is prepared for the pandemic.]
#     [C2] Unprepared: 22 +/- 2.49 s.d. out of 93 subjects (23.66%) [Those who believe their hospital/unit is unprepared for the pandemic.]
#     [C3] Unclear/irrelevant/no response: 13 +/- 1.41 s.d. out of 93 subjects (13.98%) [Those who did not provide a clear response about the preparedness of their unit/hospital.]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Good Preparations: 44 +/- 5.85 s.d. out of 93 subjects (47.31%) [Those who commended the preparedness of their unit/hospital.]
#     [C1.2] Timely Adjustments: 11 +/- 3.29 s.d. out of 93 subjects (11.83%) [Those who believe their unit/hospital was initially unprepared, but has since adjusted well.]
#     [C1.3] Optimistic About Future: 3 +/- 1.52 s.d. out of 93 subjects (3.23%) [Those who believe their unit/hospital is more prepared now than before and is optimistic about handling future situations.]
#     [C2.1] Criticisms of Preparations: 20 +/- 1.82 s.d. out of 93 subjects (21.51%) [Those who criticized the preparedness of their unit/hospital.]
#     [C2.2] Adjustments Needed: 4 +/- 0.71 s.d. out of 93 subjects (4.30%) [Those who believe their unit/hospital was initially unprepared and needs to adjust.]
#     [C3.1] Irrelevant Responses: 6 +/- 1.64 s.d. out of 93 subjects (6.45%) [Those who provided responses that didn't directly answer the question.]
#     [C3.2] No Response: 6 +/- 0.45 s.d. out of 93 subjects (6.45%) [Those who provided no response to the question.]
#
# Question Q25 - How do you think this crisis has affected you emotionally?
#   Primary Clusters:
#     [C1] Positively: 1 +/- 0.89 s.d. out of 93 subjects (1.08%) [Affected by the crisis positively]
#     [C2] Negatively: 59 +/- 2.55 s.d. out of 93 subjects (63.44%) [Experiencing negative emotions or changes due to the crisis ]
#     [C3] Mix of Positively and Negatively: 22 +/- 2.41 s.d. out of 93 subjects (23.66%) [Experiencing both positive and negative emotions or changes due to the crisis]
#     [C4] Neutral: 8 +/- 0.84 s.d. out of 93 subjects (8.60%) [Experiencing no significant emotional change due to the crisis]
#     [C5] Unclear/irrelevant/no response: 1 +/- 0.84 s.d. out of 93 subjects (1.08%) [Sentiments are unclear, irrelevant, or not stated]
#     Total # subjects across all Primary clusters: 91 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Feeling Grateful: 5 +/- 4.0 s.d. out of 93 subjects (5.38%) [Feeling gratitude or appreciative in the crisis]
#     [C1.2] Industry Pride: 1 +/- 0.55 s.d. out of 93 subjects (1.08%) [Feeling pride or purpose due to their role in healthcare ]
#     [C2.1] Anger or Frustration: 22 +/- 5.13 s.d. out of 93 subjects (23.66%) [Feeling frustration or anger due to the crisis]
#     [C2.2] Sad or Depressed: 26 +/- 5.41 s.d. out of 93 subjects (27.96%) [Facing sadness or depressive feelings due to the crisis]
#     [C2.3] Anxious or Stress: 49 +/- 8.96 s.d. out of 93 subjects (52.69%) [Feeling anxious or stressed due to the crisis]
#     [C2.4] Feeling Helpless: 10 +/- 3.36 s.d. out of 93 subjects (10.75%) [Feeling helpless or powerless in the crisis]
#     [C3.1] Mixed Emotions: 13 +/- 1.82 s.d. out of 93 subjects (13.98%) [Feeling a wide mixture of both positive and negative emotions due to the crisis]
#     [C3.2] Improving State: 10 +/- 0.71 s.d. out of 93 subjects (10.75%) [Initially negatively affected but now stabilizing or improving]
#     [C3.3] Worsening State: 3 +/- 1.41 s.d. out of 93 subjects (3.23%) [Initially positively or neutrally effective, but now experiencing negative effects]
#     [C4.1] Minimal Effect: 5 +/- 0.71 s.d. out of 93 subjects (5.38%) [Feeling little to no significant emotional change due to the crisis]
#     [C4.2] Adjusting: 4 +/- 0.84 s.d. out of 93 subjects (4.30%) [Adjusting or becoming used to the situation]
#     [C5.1] Inconclusive Statements: 1 +/- 0.45 s.d. out of 93 subjects (1.08%) [Statements that do not decisively provide an emotional state]
#     [C5.2] Missing Response: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Missing or non-existent sentiment statement]
#
# Question Q26 - Do you feel supported by peers and/or family during this time?
#   Primary Clusters:
#     [C1] Yes: 85 +/- 0.84 s.d. out of 93 subjects (91.40%) [Subjects feel supported by peers and/or family.]
#     [C3] Mixed: 7 +/- 0.84 s.d. out of 93 subjects (7.53%) [Subjects feel supported by some (peers or family) but not by others.]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] General affirmation: 53 +/- 1.79 s.d. out of 93 subjects (56.99%) [Subjects simply affirmed they feel supported.]
#     [C1.2] Elaborated affirmation: 31 +/- 2.17 s.d. out of 93 subjects (33.33%) [Subjects affirmed they feel supported with additional explanation or elaboration.]
#     [C1.3] Support mainly from specific people or groups: 1 +/- 1.79 s.d. out of 93 subjects (1.08%) [Subjects affirmed feeling supported primarily by specific people or groups (e.g. coworkers, spouse).]
#     [C3.1] Support from family but not peers: 5 +/- 0.84 s.d. out of 93 subjects (5.38%) [Subjects feel supported by family, but not by peers.]
#     [C3.2] Support from peers but not family: 3 +/- 0.71 s.d. out of 93 subjects (3.23%) [Subjects feel supported by peers, but not family.]
#
# Question Q27 - Have you had more problems with family during this time?
#   Primary Clusters:
#     [C1] Yes: 26 +/- 2.0 s.d. out of 93 subjects (27.96%) [Subjects mentioned having more problems with family during the COVID-19 pandemic]
#     [C2] No: 50 +/- 1.82 s.d. out of 93 subjects (53.76%) [Subjects clearly expressed not having more problems with family during the pandemic.]
#     [C3] Unclear/irrelevant/no response: 16 +/- 0.55 s.d. out of 93 subjects (17.20%) [Subjects gave answers that were unclear or irrelevant, or there was no response from the subject]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Differing views on pandemic: 3 +/- 0.55 s.d. out of 93 subjects (3.23%) [Subjects in cluster C1 mentioned conflicts caused by differing views on the impact of the pandemic.]
#     [C1.2] COVID-related health issues: 4 +/- 0.71 s.d. out of 93 subjects (4.30%) [Subjects in cluster C1 noted conflicts or issues caused by family members testing positive for COVID or experiencing COVID-like symptoms.]
#     [C1.3] Increased tensions/frustrations: 7 +/- 1.64 s.d. out of 93 subjects (7.53%) [Subjects in cluster C1 reported increased tensions or bickering within the family.]
#     [C1.4] Stress due to stay-at-home situation: 4 +/- 0.84 s.d. out of 93 subjects (4.30%) [Subjects in cluster C1 talked about issues related to stress or anxiety caused by the stay-at-home situation.]
#     [C1.5] Logistical issues: 3 +/- 1.1 s.d. out of 93 subjects (3.23%) [Subjects in cluster C1 mentioned problems due to logistical or practical constraints imposed by the pandemic.]
#     [C1.6] Disrupted routines: 3 +/- 0.84 s.d. out of 93 subjects (3.23%) [Subjects in cluster C1 referred to problems stemming from disrupted routines, such as kids' school schedules.]
#     [C2.1] No issues but references to family: 4 +/- 1.52 s.d. out of 93 subjects (4.30%) [Even though subjects in cluster C2 noted no direct issues with family, they made mention of family matters indirectly.]
#     [C2.2] Family support or improvement in relationships: 5 +/- 0.84 s.d. out of 93 subjects (5.38%) [Subjects in cluster C2 indicated experiencing support from their family or improvement in their family relationships during the pandemic.]
#
# Question Q28 - Before this crisis, if someone asked you about your burnout level, what would you have answered?
#   Primary Clusters:
#     [C1] No/Mild burnout level: 57 +/- 1.0 s.d. out of 93 subjects (61.29%) [Individuals rated their burnout level as 1, 2, or 3 out of 10, or provided similar indicators of no or mild burnout such as 'low', 'not burned out', 'zero', 'minimal', or 'mild'.]
#     [C2] Moderate burnout level: 20 +/- 1.14 s.d. out of 93 subjects (21.51%) [Individuals rated their burnout level as 4, 5, or 6 out of 10, or provided similar indicators of moderate burnout such as 'moderate' or 'felt the pressure but coping'.]
#     [C3] Severe burnout level: 13 +/- 0.55 s.d. out of 93 subjects (13.98%) [Individuals rated their burnout level as 7, 8, 9, or 10 out of 10, or provided similar indicators of severe burnout such as 'high', 'tired and exhausted', 'pretty burnt out', 'feeling burnt out', or 'high (unrelated to COVID-19)'.]
#     [C4] Unclear/irrelevant/no response: 2 +/- 0.0 s.d. out of 93 subjects (2.15%) [Individuals did not provide a clear response, or did not respond at all.]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Explicitly stated low/no burnout: 43 +/- 7.26 s.d. out of 93 subjects (46.24%) [Subjects within the No/Mild burnout level group explicitly stated 'low', 'zero', 'no burnout' or similar.]
#     [C1.2] Quantified low burnout level: 17 +/- 1.48 s.d. out of 93 subjects (18.28%) [Subjects within the No/Mild burnout level group quantified their burnout level as 1, 2, or 3 out of 10.]
#     [C2.1] Explicitly stated moderate burnout: 3 +/- 0.55 s.d. out of 93 subjects (3.23%) [Subjects within the Moderate burnout level group explicitly stated 'moderate' or similar.]
#     [C2.2] Quantified moderate burnout level: 16 +/- 1.3 s.d. out of 93 subjects (17.20%) [Subjects within the Moderate burnout level group quantified their burnout level as 4, 5, or 6 out of 10.]
#     [C3.1] Explicitly stated high burnout: 6 +/- 0.45 s.d. out of 93 subjects (6.45%) [Subjects within the Severe burnout level group explicitly stated 'high', 'tired and exhausted', 'pretty burnt out', 'feeling burnt out', or 'high burnout (unrelated to COVID-19)' or similar.]
# ...
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Opportunities and Growth: 12 +/- 4.83 s.d. out of 93 subjects (12.90%) [Responses mentioning new opportunities, growth or learning due to crisis]
#     [C1.2] Improved Preparedness: 13 +/- 3.36 s.d. out of 93 subjects (13.98%) [Responses mentioning improvements in preparedness or better approaches to crises]
#     [C1.3] Positive Impact on Career: 7 +/- 2.61 s.d. out of 93 subjects (7.53%) [Responses mentioning positive impact on career or professional growth]
#     [C2.1] Anticipated Difficulties: 14 +/- 9.93 s.d. out of 93 subjects (15.05%) [Responses mentioning expected struggles, difficulties or negative changes due to crisis]
#     [C2.2] Health Concerns: 8 +/- 3.7 s.d. out of 93 subjects (8.60%) [Responses mentioning health concerns for self or family due to crisis]
#     [C2.3] Economic Concerns: 8 +/- 1.87 s.d. out of 93 subjects (8.60%) [Responses expressing economic or financial concerns due to crisis]
#     [C2.4] Altered Lifestyle: 20 +/- 4.34 s.d. out of 93 subjects (21.51%) [Responses expressing significant alterations in lifestyle due to crisis]
#     [C2.5] Uncertainty: 17 +/- 5.81 s.d. out of 93 subjects (18.28%) [Responses expressing uncertainty or anxiety about the future due to crisis]
#     [C2.6] Career Concerns: 14 +/- 1.95 s.d. out of 93 subjects (15.05%) [Responses expressing professional or career-related concerns due to crisis]
#
# Question Q33 - What impact do you see this crisis having on you about five years from now?
#   Primary Clusters:
#     [C1] Positive: 51 +/- 4.21 s.d. out of 93 subjects (54.84%) [Responses that reflect a hopeful or positive outlook]
#     [C2] Negative: 9 +/- 3.21 s.d. out of 93 subjects (9.68%) [Responses that reflect a negative or pessimistic outlook]
#     [C3] Neutral/Mixed: 19 +/- 3.71 s.d. out of 93 subjects (20.43%) [Responses that maintain a neutral stand or reflect mixed feelings]
#     [C4] Unclear/irrelevant/no response: 12 +/- 1.73 s.d. out of 93 subjects (12.90%) [Responses that are unclear, irrelevant or non-existent]
#     Total # subjects across all Primary clusters: 91 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Hopeful outlook: 9 +/- 3.49 s.d. out of 93 subjects (9.68%) [General hopeful outlook without specific details]
#     [C1.2] Personal Growth: 21 +/- 6.88 s.d. out of 93 subjects (22.58%) [Expectation of personal growth, preparedness or learned lessons]
#     [C1.3] Healthcare Improvement: 18 +/- 3.78 s.d. out of 93 subjects (19.35%) [Expectation of improvements or advancements in healthcare systems or protocols]
#     [C1.4] Return to Normal: 13 +/- 3.58 s.d. out of 93 subjects (13.98%) [Hopes for a return to 'normal,' recovery or resolution of the crisis]
#     [C2.1] Personal Impact: 9 +/- 3.32 s.d. out of 93 subjects (9.68%) [Negative impact on individual's life, work or mental state]
#     [C2.2] Healthcare Impact: 1 +/- 0.58 s.d. out of 93 subjects (1.08%) [Negative impact on healthcare practices, systems or protocols]
#     [C3.1] Neutral: 10 +/- 2.17 s.d. out of 93 subjects (10.75%) [Uncertain about impact or maintaining neutral expectations]
#     [C3.2] Mixed: 9 +/- 3.44 s.d. out of 93 subjects (9.68%) [Mixed feelings, potential pros and cons outlined]
#     [C4.1] No Response: 7 +/- 0.45 s.d. out of 93 subjects (7.53%) [No response or 'NA']
#     [C4.2] Unclear Response: 4 +/- 2.17 s.d. out of 93 subjects (4.30%) [Ambiguous, unclear or irrelevant responses]
#
# Question Q34 - Would you seek help if you felt burned out? How?
#   Primary Clusters:
#     [C1] Yes: 83 +/- 1.3 s.d. out of 93 subjects (89.25%) [Subjects who answered 'Yes' to seeking help for burnout]
#     [C2] No: 5 +/- 0.0 s.d. out of 93 subjects (5.38%) [Subjects who answered 'No' to seeking help for burnout]
#     [C3] Unclear/irrelevant/no response: 4 +/- 1.3 s.d. out of 93 subjects (4.30%) [Subjects whose response was unclear, irrelevant, or did not respond]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Professional help: 54 +/- 5.17 s.d. out of 93 subjects (58.06%) [Subjects who mentioned seeking professional help, including medical, psychological, counseling services, or workplace resources]
#     [C1.2] Peer support: 28 +/- 4.45 s.d. out of 93 subjects (30.11%) [Subjects who mentioned turning to peers, colleagues, or their professional network for support]
#     [C1.3] Personal network: 25 +/- 0.89 s.d. out of 93 subjects (26.88%) [Subjects who mentioned seeking help from their personal network, such as family or friends]
#     [C1.4] Specific organizations: 8 +/- 0.89 s.d. out of 93 subjects (8.60%) [Subjects who referred specifically to Baylor or other precise entities for support]
#
# Question Q35 - Would you change jobs or career trajectories?  [ONLY nonstudents]
#   Primary Clusters:
#     [C1] Yes: 25 +/- 3.21 s.d. out of 73 subjects (34.25%) [Subjects who explicitly expressed a willingness to consider changing jobs/careers.]
#     [C2] No: 40 +/- 1.79 s.d. out of 73 subjects (54.79%) [Subjects who clearly stated they would not consider changing jobs/careers.]
#     [C3] Unclear/irrelevant/no response: 6 +/- 4.38 s.d. out of 73 subjects (8.22%) [Subjects who were ambivalent, did not give clear answers, or provided no response.]
#     Total # subjects across all Primary clusters: 71 out of 73 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Yes - Immediate: 11 +/- 3.97 s.d. out of 73 subjects (15.07%) [Subjects who expressed an immediate willingness to change jobs or careers.]
#     [C1.2] Yes - Contextual: 13 +/- 3.03 s.d. out of 73 subjects (17.81%) [Subjects who mentioned willingness to change job under contextual situations like the current situation getting worse, high stress level or a good opportunity.]
#     [C1.3] Yes - Prior consideration: 1 +/- 0.0 s.d. out of 73 subjects (1.37%) [Subjects who had contemplated changing jobs or careers prior to COVID-19.]
#     [C2.1] No - Job satisfaction: 6 +/- 1.64 s.d. out of 73 subjects (8.22%) [Subjects who expressed satisfaction and passion for their current jobs.]
#     [C2.2] No - Retirement Consideration: 1 +/- 0.89 s.d. out of 73 subjects (1.37%) [Subjects who expressed more inclination towards retirement than changing jobs.]
#     [C2.3] No - Contractual obligation: 1 +/- 0.0 s.d. out of 73 subjects (1.37%) [Subjects who could not change jobs due to contractual obligations.]
#
# Question Q36 - Has this crisis affected your specialty decision or career plans in any way?  [ONLY students]
#   Primary Clusters:
#     [C1] Yes: 7 +/- 0.45 s.d. out of 20 subjects (35.00%) [Responses indicating the crisis has affected the subject's specialty decision or career plans]
#     [C2] No: 10 +/- 0.45 s.d. out of 20 subjects (50.00%) [Responses indicating the crisis has not affected the subject's specialty decision or career plans]
#     [C3] Unclear/irrelevant/no response: 2 +/- 0.0 s.d. out of 20 subjects (10.00%) [Responses that do not provide a clear answer to the question or simply do not respond to the question]
#     Total # subjects across all Primary clusters: 19 out of 20 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1] Yes: 1 +/- nan s.d. out of 20 subjects (5.00%) [Responses indicating the crisis has affected the subject's specialty decision or career plans]
#     [C1.1] Change in Specialty: 4 +/- 0.55 s.d. out of 20 subjects (20.00%) [Responses indicating a change in specialty due to the crisis]
#     [C1.2] Change in Work Preferences: 3 +/- 0.89 s.d. out of 20 subjects (15.00%) [Responses indicating a change in work preferences due to the crisis (such as research, location etc.)]
#     [C2.1] Explicit No: 10 +/- 0.0 s.d. out of 20 subjects (50.00%) [Responses explicitly stating "No", symbolizing no effect of crisis]
#     [C2.2] Implied No: 1 +/- nan s.d. out of 20 subjects (5.00%) [Responses implicitly indicating no effect without specifically stating "No"]
#     [C3.1] Not Addressed: 2 +/- 0.0 s.d. out of 20 subjects (10.00%) [Responses where the subject does not address the question]
#     [C3.2] Question not Asked: 2 +/- 0.0 s.d. out of 20 subjects (10.00%) [In cases where the question was not asked in the interview]
#
# Question Q37 - Would you get (professional or other) help/care if you felt mentally overwhelmed? How? When?
#   Primary Clusters:
#     [C1] Yes will get professional help: 59 +/- 2.97 s.d. out of 93 subjects (63.44%) [The subject indicated that they would seek professional mental health support if they felt overwhelmed.]
#     [C2] Yes but not professional help: 8 +/- 1.3 s.d. out of 93 subjects (8.60%) [The subject indicated that they would seek help but not necessarily from a professional mental health source, instead using personal networks or self-help strategies.]
#     [C3] Mixed: 22 +/- 3.32 s.d. out of 93 subjects (23.66%) [The subject did not clearly indicate only one option, but a combination of seeking help both professionally or personally.]
#     [C4] Will not seek/get help: 3 +/- 0.0 s.d. out of 93 subjects (3.23%) [The subject indicated that they would not seek mental health support if they felt overwhelmed.]
#     [C5] Unclear/irrelevant/no response: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [The subject did not respond clearly to the question or the response is irrelevant.]
#     Total # subjects across all Primary clusters: 93 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Hospital/Therapist: 45 +/- 4.0 s.d. out of 93 subjects (48.39%) [The subject would seek professional help specifically from a hospital resource or a therapist.]
#     [C1.2] Workplace Resource: 16 +/- 2.51 s.d. out of 93 subjects (17.20%) [The subject would seek professional help specifically from a workplace resource.]
#     [C1.3] Psychiatrist: 9 +/- 1.95 s.d. out of 93 subjects (9.68%) [The subject would seek professional help specifically from a psychiatrist.]
#     [C2.1] Friends/Family: 21 +/- 1.87 s.d. out of 93 subjects (22.58%) [The subject would seek help from their personal network, such as friends or family.]
#     [C2.2] Employer/Fellow Staff: 13 +/- 3.11 s.d. out of 93 subjects (13.98%) [The subject would seek help from their employer or colleagues.]
#     [C2.3] Self-help: 3 +/- 1.3 s.d. out of 93 subjects (3.23%) [The subject would resort to self-help strategies, such as exercise or meditation.]
#
# Question Q38 - Any obstacles you foresee in getting help if you needed to?
#   Primary Clusters:
#     [C1] Yes: 43 +/- 1.14 s.d. out of 93 subjects (46.24%) [Subjects foresee obstacles in getting help if needed]
#     [C2] No: 46 +/- 0.71 s.d. out of 93 subjects (49.46%) [Subjects do not foresee obstacles in getting help if needed]
#     [C3] Unclear/irrelevant/no response: 3 +/- 1.14 s.d. out of 93 subjects (3.23%) [Not clear if subjects foresee obstacles in getting help if needed or they did not provide a response]
#     Total # subjects across all Primary clusters: 92 out of 93 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Access and logistics: 20 +/- 2.61 s.d. out of 93 subjects (21.51%) [Subjects identified logistical issues such as access to healthcare, scheduling, and availability of services as obstacles ]
#     [C1.2] Social stigma: 16 +/- 1.3 s.d. out of 93 subjects (17.20%) [Subjects identified social stigma and professional repercussions as obstacles]
#     [C1.3] Reluctance to Seek Aid: 2 +/- 0.84 s.d. out of 93 subjects (2.15%) [Subjects identified reluctance or difficulty in admitting the need for help as obstacles]
#     [C1.4] Telehealth and Virtual Aid Issues Subjects identified changes to remote help or issues with telehealth as obstacles: 5 +/- 1.0 s.d. out of 93 subjects (5.38%) [nan]
#     [C1.5] Personal and Internal Barriers: 7 +/- 3.7 s.d. out of 93 subjects (7.53%) [Subjects identified personal and internal barriers, such as lack of time, trust, or ability to recognize the need for help, as obstacles.]
#     [C2.1] Explicit Denial: 41 +/- 1.52 s.d. out of 93 subjects (44.09%) [Subjects explicitly stated that they do not foresee obstacles]
#     [C2.2] Indirect Denial: 4 +/- 1.95 s.d. out of 93 subjects (4.30%) [Subjects indirectly indicated that they do not foresee obstacles]
#     [C3.1] Ambiguous Response: 2 +/- 1.14 s.d. out of 93 subjects (2.15%) [Responses are ambiguous or provide inadequate information to discern whether subjects foresee obstacles]
#     [C3.2] No Response: 1 +/- 0.0 s.d. out of 93 subjects (1.08%) [Subjects provided no response]
#
# Question Q39 - If student or trainee, how closely do you feel that you are adhering to the Hippocratic oath during this time?  [ONLY students]
#   Primary Clusters:
#     [C1] Adhering Closely: 14 +/- 0.0 s.d. out of 20 subjects (70.00%) [Subjects that believe they are closely adhering to the Hippocratic oath during the specified time.]
#     [C2] Not adhering closely OR Adhering conditionally: 2 +/- 0.55 s.d. out of 20 subjects (10.00%) [Subjects that either don't believe they're strictly adhering to the Hippocratic oath or are conditionally adhering to it depending on specific circumstances.]
#     [C3] Unclear/irrelevant/no response: 3 +/- 0.55 s.d. out of 20 subjects (15.00%) [Subjects with no clear response, have irrelevant answers, or didn't respond.]
#     Total # subjects across all Primary clusters: 19 out of 20 subjects ignoring s.d.
#   Secondary Clusters [non-exclusive membership]:
#     [C1.1] Explicitly Stated Adherence: 12 +/- 1.14 s.d. out of 20 subjects (60.00%) [Subjects that explicitly stated they're adhering closely to the Hippocratic oath.]
#     [C1.2] Adherence through Actions: 2 +/- 0.89 s.d. out of 20 subjects (10.00%) [Subjects that expressed their adherence through mentioning of particular actions, interventions or behaviors.]
#     [C2.1] Somewhat Adherence: 1 +/- 0.45 s.d. out of 20 subjects (5.00%) [Subjects that expressed they are somewhat adhering but not completely.]
#     [C2.2] Conditional Adherence: 1 +/- 0.55 s.d. out of 20 subjects (5.00%) [Subjects whose adherence depends on specific circumstances or conditions.]
#
# Question Q40 - If student or trainee, do you agree with your school's policies regarding medical students' roles at this time?  [ONLY students]
#   Primary Clusters:
#     [C1] Yes: 10 +/- 0.45 s.d. out of 20 subjects (50.00%) [Subjects agree with their school's policies]
#     [C2] No: 3 +/- 0.45 s.d. out of 20 subjects (15.00%) [Subjects don't agree with their school's policies]
#     [C3] Mixed/Conditionally: 3 +/- 0.55 s.d. out of 20 subjects (15.00%) [Subjects agree but with some concerns or conditional on certain factors ]
#     [C4] Unclear/irrelevant/no response: 3 +/- 0.0 s.d. out of 20 subjects (15.00%) [Subjects did not respond, the question was not applicable, or the subjects' responses were unclear]
#     Total # subjects across all Primary clusters: 19 out of 20 subjects ignoring s.d.
#   Secondary Clusters:
#     [C1.1] Yes - Unqualified Agreement: 8 +/- 0.0 s.d. out of 20 subjects (40.00%) [Subjects agree completely with their school's policies]
#     [C1.2] Yes - Concerns: 1 +/- nan s.d. out of 20 subjects (5.00%) [Subjects agree but express concerns or doubts]
#     [C1.3] Yes - Positive Justification: 2 +/- 0.0 s.d. out of 20 subjects (10.00%) [Subjects agree and provide a detailed positive reason or explanation for their agreement]
#     [C2.1] No - Unqualified Disagreement: 3 +/- 0.0 s.d. out of 20 subjects (15.00%) [Subjects do not agree with their school's policies and provide no further explanation for their disagreement]
#     [C2.2] No - Negative Justification: 1 +/- nan s.d. out of 20 subjects (5.00%) [Subjects do not agree and provide a detailed negative reason or explanation for their disagreement]
#     [C3.1] Mixed - Concerns: 3 +/- 0.55 s.d. out of 20 subjects (15.00%) [Subjects agree tentatively or with stated reservations or concerns]
#     [C4.3] No response: 3 +/- 0.0 s.d. out of 20 subjects (15.00%) [No response was given by the subject]

# %%
# Bar plots
filename = f"{OUTPUT_DIR}/bar_charts_reclustered.pdf"
if not os.path.exists(f"{OUTPUT_DIR}/bar_charts"):
    os.makedirs(f"{OUTPUT_DIR}/bar_charts")
pdf = matplotlib.backends.backend_pdf.PdfPages(filename=filename)
for q_idx, q_data in cluster_report.items():
    # Extract data
    Q = q_idx
    question = q_data["question"]
    cluster_defs = q_data["cluster_def"]
    per_cluster_data = q_data["primary_cluster_mean_stds"]

    # Check if non-exclusive
    is_primary_non_exclusive = q_data["is_primary_non_exclusive"]
    if is_primary_non_exclusive:
        title_suffix = "[non-exclusive membership]"
    else:
        title_suffix = ""

    # Check if population-specific question & subset
    specific_population = q_data["specific_population"]
    if specific_population is not None:
        title_suffix += f" [Only {specific_population}]"

    # Get cluster names
    cluster_names = []
    for cluster_id in per_cluster_data["cluster_ids"].values:
        cluster_name = cluster_defs[cluster_defs["cluster_id"] == cluster_id][
            "cluster_name"
        ].values[0]
        cluster_names.append(cluster_name)

    # Wrap text for long cluster names
    labels = [
        "\n".join(
            textwrap.wrap(
                cluster_name, width=20, break_long_words=False, break_on_hyphens=False
            )
        )
        for cluster_name in cluster_names
    ]

    # Setup plot
    colors = plt.cm.tab20c.colors
    fig, ax = plt.subplots(figsize=(6, 2.5))

    ax.set_ylabel("Number of Subjects")
    wrapped_title = "\n".join(
        textwrap.wrap(f"{Q}: {question}\n{title_suffix} ", width=60)
    )
    ax.set_title(f"{wrapped_title}", pad=10)  # Add padding

    # Add bars
    cluster_ids = per_cluster_data["cluster_ids"].values
    counts = per_cluster_data["count_mean"].values
    stds = per_cluster_data["count_std"].values
    # ax.bar(cluster_ids, counts, yerr=stds, capsize=5)
    ax.bar(
        cluster_ids,
        counts,
        yerr=stds,
        capsize=5,
        align="center",
        alpha=0.7,
        color=colors[: len(counts)],
    )
    ax.set_xticks(cluster_ids)
    ax.set_xticklabels(labels, rotation=90)

    # Save figure
    individual_filename = f"{OUTPUT_DIR}/bar_charts/question_{q_idx}.pdf"
    plt.savefig(individual_filename, bbox_inches="tight")
    print(f"Saved {individual_filename}")

    pdf.savefig(fig, bbox_inches="tight")
    # plt.show()
    plt.close()
pdf.close()
print(f"Saved {filename}")
# Out:
# Saved ./outputs/20231227//bar_charts/question_Q00.pdf
# Saved ./outputs/20231227//bar_charts/question_Q01.pdf
# Saved ./outputs/20231227//bar_charts/question_Q02.pdf
# Saved ./outputs/20231227//bar_charts/question_Q03.pdf
# Saved ./outputs/20231227//bar_charts/question_Q04.pdf
# Saved ./outputs/20231227//bar_charts/question_Q05.pdf
# Saved ./outputs/20231227//bar_charts/question_Q06.pdf
# Saved ./outputs/20231227//bar_charts/question_Q07.pdf
# Saved ./outputs/20231227//bar_charts/question_Q08.pdf
# Saved ./outputs/20231227//bar_charts/question_Q09.pdf
# Saved ./outputs/20231227//bar_charts/question_Q10.pdf
# Saved ./outputs/20231227//bar_charts/question_Q11.pdf
# Saved ./outputs/20231227//bar_charts/question_Q12.pdf
# Saved ./outputs/20231227//bar_charts/question_Q13.pdf
# Saved ./outputs/20231227//bar_charts/question_Q14.pdf
# Saved ./outputs/20231227//bar_charts/question_Q15.pdf
# Saved ./outputs/20231227//bar_charts/question_Q16.pdf
# Saved ./outputs/20231227//bar_charts/question_Q17.pdf
# Saved ./outputs/20231227//bar_charts/question_Q18.pdf
# Saved ./outputs/20231227//bar_charts/question_Q19.pdf
# Saved ./outputs/20231227//bar_charts/question_Q20.pdf
# Saved ./outputs/20231227//bar_charts/question_Q21.pdf
# Saved ./outputs/20231227//bar_charts/question_Q22.pdf
# Saved ./outputs/20231227//bar_charts/question_Q23.pdf
# Saved ./outputs/20231227//bar_charts/question_Q24.pdf
# Saved ./outputs/20231227//bar_charts/question_Q25.pdf
# Saved ./outputs/20231227//bar_charts/question_Q26.pdf
# Saved ./outputs/20231227//bar_charts/question_Q27.pdf
# Saved ./outputs/20231227//bar_charts/question_Q28.pdf
# Saved ./outputs/20231227//bar_charts/question_Q29.pdf
# Saved ./outputs/20231227//bar_charts/question_Q30.pdf
# Saved ./outputs/20231227//bar_charts/question_Q31.pdf
# Saved ./outputs/20231227//bar_charts/question_Q32.pdf
# Saved ./outputs/20231227//bar_charts/question_Q33.pdf
# Saved ./outputs/20231227//bar_charts/question_Q34.pdf
# Saved ./outputs/20231227//bar_charts/question_Q35.pdf
# Saved ./outputs/20231227//bar_charts/question_Q36.pdf
# Saved ./outputs/20231227//bar_charts/question_Q37.pdf
# Saved ./outputs/20231227//bar_charts/question_Q38.pdf
# Saved ./outputs/20231227//bar_charts/question_Q39.pdf
# Saved ./outputs/20231227//bar_charts/question_Q40.pdf
# Saved ./outputs/20231227//bar_charts_reclustered.pdf

# %%
filename = f"{OUTPUT_DIR}/bar_charts_reclustered.pdf"
if not os.path.exists(f"{OUTPUT_DIR}/bar_charts"):
    os.makedirs(f"{OUTPUT_DIR}/bar_charts")
pdf = matplotlib.backends.backend_pdf.PdfPages(filename=filename)

for q_idx, q_data in cluster_report.items():
    # Extract data
    Q = q_idx
    question = q_data["question"]
    cluster_defs = q_data["cluster_def"]
    per_cluster_data = q_data["primary_cluster_mean_stds"]

    # Check if non-exclusive
    is_primary_non_exclusive = q_data["is_primary_non_exclusive"]
    title_suffix = "[non-exclusive membership]" if is_primary_non_exclusive else ""

    # Check if population-specific question & subset
    specific_population = q_data["specific_population"]
    if specific_population is not None:
        title_suffix += f" [Only {specific_population}]"

    # Get cluster names
    cluster_names = [
        cluster_defs[cluster_defs["cluster_id"] == cluster_id]["cluster_name"].values[0]
        for cluster_id in per_cluster_data["cluster_ids"].values
    ]

    # Wrap text for long cluster names
    labels = [
        "\n".join(
            textwrap.wrap(
                cluster_name, width=20, break_long_words=False, break_on_hyphens=False
            )
        )
        for cluster_name in cluster_names
    ]

    # Setup plot for horizontal bars
    colors = plt.cm.tab20c.colors
    # fig, ax = plt.subplots(
    #     figsize=(10, len(cluster_names) * 0.5)
    # )  # Adjust figure size based on the number of clusters
    fig, ax = plt.subplots(
        figsize=(2.5, max(3, len(cluster_names) * 0.7))
    )  # Adjust figure size based on the number of clusters

    ax.set_xlabel("Number of Subjects")
    wrapped_title = "\n".join(
        textwrap.wrap(f"{Q}: {question} {title_suffix}", width=80)
    )
    ax.set_title(f"{wrapped_title}", pad=20)

    # Add horizontal bars
    cluster_ids = range(
        len(cluster_names)
    )  # Use sequential numbers as cluster IDs for y-axis
    counts = per_cluster_data["count_mean"].values
    stds = per_cluster_data["count_std"].values
    ax.barh(
        cluster_ids,
        counts,
        xerr=stds,
        capsize=5,
        align="center",
        alpha=0.7,
        color=colors[: len(counts)],
    )
    ax.set_yticks(cluster_ids)
    ax.set_yticklabels(labels)
    ax.invert_yaxis()  # Invert y-axis so the first item is on top

    # Save figure
    individual_filename = f"{OUTPUT_DIR}/bar_charts/question_{q_idx}.pdf"
    plt.savefig(individual_filename, bbox_inches="tight")
    print(f"Saved {individual_filename}")

    pdf.savefig(fig, bbox_inches="tight")
    # plt.show()
    plt.close()

pdf.close()
print(f"Saved {filename}")
# Out:
# Saved ./outputs/20231227//bar_charts/question_Q00.pdf
# Saved ./outputs/20231227//bar_charts/question_Q01.pdf
# Saved ./outputs/20231227//bar_charts/question_Q02.pdf
# Saved ./outputs/20231227//bar_charts/question_Q03.pdf
# Saved ./outputs/20231227//bar_charts/question_Q04.pdf
# Saved ./outputs/20231227//bar_charts/question_Q05.pdf
# Saved ./outputs/20231227//bar_charts/question_Q06.pdf
# Saved ./outputs/20231227//bar_charts/question_Q07.pdf
# Saved ./outputs/20231227//bar_charts/question_Q08.pdf
# Saved ./outputs/20231227//bar_charts/question_Q09.pdf
# Saved ./outputs/20231227//bar_charts/question_Q10.pdf
# Saved ./outputs/20231227//bar_charts/question_Q11.pdf
# Saved ./outputs/20231227//bar_charts/question_Q12.pdf
# Saved ./outputs/20231227//bar_charts/question_Q13.pdf
# Saved ./outputs/20231227//bar_charts/question_Q14.pdf
# Saved ./outputs/20231227//bar_charts/question_Q15.pdf
# Saved ./outputs/20231227//bar_charts/question_Q16.pdf
# Saved ./outputs/20231227//bar_charts/question_Q17.pdf
# Saved ./outputs/20231227//bar_charts/question_Q18.pdf
# Saved ./outputs/20231227//bar_charts/question_Q19.pdf
# Saved ./outputs/20231227//bar_charts/question_Q20.pdf
# Saved ./outputs/20231227//bar_charts/question_Q21.pdf
# Saved ./outputs/20231227//bar_charts/question_Q22.pdf
# Saved ./outputs/20231227//bar_charts/question_Q23.pdf
# Saved ./outputs/20231227//bar_charts/question_Q24.pdf
# Saved ./outputs/20231227//bar_charts/question_Q25.pdf
# Saved ./outputs/20231227//bar_charts/question_Q26.pdf
# Saved ./outputs/20231227//bar_charts/question_Q27.pdf
# Saved ./outputs/20231227//bar_charts/question_Q28.pdf
# Saved ./outputs/20231227//bar_charts/question_Q29.pdf
# Saved ./outputs/20231227//bar_charts/question_Q30.pdf
# Saved ./outputs/20231227//bar_charts/question_Q31.pdf
# Saved ./outputs/20231227//bar_charts/question_Q32.pdf
# Saved ./outputs/20231227//bar_charts/question_Q33.pdf
# Saved ./outputs/20231227//bar_charts/question_Q34.pdf
# Saved ./outputs/20231227//bar_charts/question_Q35.pdf
# Saved ./outputs/20231227//bar_charts/question_Q36.pdf
# Saved ./outputs/20231227//bar_charts/question_Q37.pdf
# Saved ./outputs/20231227//bar_charts/question_Q38.pdf
# Saved ./outputs/20231227//bar_charts/question_Q39.pdf
# Saved ./outputs/20231227//bar_charts/question_Q40.pdf
# Saved ./outputs/20231227//bar_charts_reclustered.pdf
